# %% [markdown]
# # Semana 2 - Desafio de Qualidade
#
# Olá, me chamo Wesley e este é meu notebook que contém as resoluções para o desafio proposto na semana 2 da Aceleração PySpark na Capgemini.
#
# O desafio consiste em garantir a qualidade dos dados contidos em três datasets (Airports, Planes e Flights) que serão respectivamente resolvidos, juntos com os exercícios propostos para esta semana.
#
# Por fim, para colocarmos as mãos na massa, é importante lembrar que neste notebook será majoritariamente feito uso do PySpark, logo não serão inclusas as bibliotecas de data science do python (pandas, numpy, etc) que constam como padrão na [documentação oficial] do PySpark, pois o intuito deste notebook é aprender, e reforçar o que foi aprendido até o momento, da programação com o PySpark.
#
# [documentação oficial]: https://spark.apache.org/docs/latest/api/python/getting_started/install.html

# %% [markdown]
# ## Vamos lá!
#
# começaremos com o setup

# %%
#installing the required packages
# !pip install pyspark
# !pip install findspark
# !pip install py4j
# Out:
# Requirement already satisfied: pyspark in /opt/python/envs/default/lib/python3.8/site-packages (3.2.0)
# Requirement already satisfied: py4j==0.10.9.2 in /opt/python/envs/default/lib/python3.8/site-packages (from pyspark) (0.10.9.2)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: py4j in /opt/python/envs/default/lib/python3.8/site-packages (0.10.9.2)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
import findspark
findspark.init()
# PySpark is the Spark API for Python. In this lab, we use PySpark to initialize the spark context. 
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %%
import re
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType

# %%
# Expressoes regulares comuns
REGEX_ALPHA    = r'[a-zA-Z]+'
REGEX_INTEGER  = r'[0-9]+'
REGEX_FLOAT    = r'[0-9]+\.[0-9]+'
REGEX_ALPHANUM = r'[0-9a-zA-Z]+'
REGEX_EMPTY_STR= r'[\t ]+$'
REGEX_SPECIAL  = r'[!@#$%&*\(\)_]+'
REGEX_NNUMBER  = r'^N[1-9][0-9]{2,3}([ABCDEFGHJKLMNPRSTUVXWYZ]{1,2})'
REGEX_NNUMBER_INVALID = r'(N0.*$)|(.*[IO].*)'
REGEX_TIME_FMT = r'^(([0-1]?[0-9])|(2[0-3]))([0-5][0-9])$'

# %%
import re
#helper functions
def check_empty_column(col):
    return (F.col(col).isNull() | (F.col(col) == '') | F.col(col).rlike(REGEX_EMPTY_STR))

def check_column_range(col, from_value, to_value, leftInclusive = False, rightIncluse = False):
    check_range_expression = "(" + str(F.col(col)) + (" >= " if leftInclusive else " > ") + str(from_value) + " and " \
                                 + str(F.col(col)) + (" <= " if rightIncluse  else " < ") +")" 
    return eval(check_range_expression)
    
def create_regex_from_list(_list):
    return r'|'.join(map(lambda x : f".*({x}).*", _list))

tailnum_chars = F.udf(lambda value: ''.join([c for c in value if not c.isdigit()])[1:])

@F.udf
def get_byregex_and_extract(r_pattern, col_to_search):
    return (getattr(re.search(r_pattern, F.col(col_to_search), re.IGNORECASE), 'groups', lambda:[""])()[0].upper())

getbyreg = F.udf(lambda r_pattern,col_to_search: getattr(re.search(r_pattern, col_to_search, re.IGNORECASE), 'groups', lambda:[u""])()[0].upper())

# %%
# Creating a spark context class
sc = SparkContext()

# Creating a spark session
spark = SparkSession \
        .builder \
        .appName("Quality Assurance Challenge") \
        .getOrCreate()

# %% [markdown]
# Essa será a configuração inicial para que possamos trabalhar os datasets nos exercícios a seguir.
#
# Os datasets Airports, Planes e Flights serão apresentados nesta ordem junto com seus respectivos exercícios. Caso haja dúvidas, não deixe de olhar os glossários que acompanham cada dataset para auxiliá-lo.
#
# # Airports Dataset
#
# ![Airport](attachment:./images/airplanes_snapshot.png "a Crowded airport")
# <p style="text-align: center;"> <a href="./glossary/airport_glossary.txt"> Airport Glossary </a> </p>
#
#
# Este dataset contém 7 tarefas que serão trabalhadas a seguir, mas primeiro, iremos importar nosso dataset abaixo:

# %%
#lets describe our file
file = "./datasets/airports.csv"

#import the classes to make the schema
from pyspark.sql.types import StructType, IntegerType, FloatType, StringType, StructField

#set our schema (that you can see on glossary)
schema = StructType([
    StructField("faa",  StringType()),
    StructField("name", StringType()),
    StructField("lat",  FloatType()),
    StructField("lon",  FloatType()),
    StructField("alt",  IntegerType()),
    StructField("tz",   FloatType()),
    StructField("dst",  StringType())
])

#and create a new dataframe 
airport_df = spark \
            .read.format("csv") \
            .option("inferSchema", "false") \
            .option("header", "True")\
            .schema(schema)\
            .csv(file)

#lets take the rdd to work with too
airport_rdd = airport_df.rdd

#don't forget to create a view (important to work with spark sql)
airport_df.createOrReplaceTempView('airports_view')

#see how great is this
airport_df.printSchema()
display(airport_rdd.collect())
# Out:
# root
#  |-- faa: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- lat: float (nullable = true)
#  |-- lon: float (nullable = true)
#  |-- alt: integer (nullable = true)
#  |-- tz: float (nullable = true)
#  |-- dst: string (nullable = true)
# [Row(faa='04G', name='Lansdowne Airport', lat=41.13047409057617, lon=-80.61958312988281, alt=1044, tz=-5.0, dst='A'),
#  Row(faa='06A', name='Moton Field Municipal Airport', lat=32.4605712890625, lon=-85.6800308227539, alt=264, tz=-5.0, dst='A'),
#  Row(faa='06C', name='Schaumburg Regional', lat=41.989341735839844, lon=-88.10124206542969, alt=801, tz=-6.0, dst='A'),
#  Row(faa='06N', name='Randall Airport', lat=41.43191146850586, lon=-74.39156341552734, alt=523, tz=-5.0, dst='A'),
#  Row(faa='09J', name='Jekyll Island Airport', lat=31.074472427368164, lon=-81.42778015136719, alt=11, tz=-4.0, dst='A'),
#  Row(faa='0A9', name='Elizabethton Municipal Airport', lat=36.37122344970703, lon=-82.17341613769531, alt=1593, tz=-4.0, dst='A'),
#  Row(faa='0G6', name='Williams County Airport', lat=41.46730422973633, lon=-84.50677490234375, alt=730, tz=-5.0, dst='A'),
#  Row(faa='0G7', name='Finger Lakes Regional Airport', lat=42.88356399536133, lon=-76.78123474121094, alt=492, tz=-5.0, dst='A'),
#  Row(faa='0P2', name='Shoestring Aviation Airfield', lat=39.794822692871094, lon=-76.6471939086914, alt=1000, tz=-5.0, dst='U'),
#  Row(faa='0S9', name='Jefferson County Intl', lat=48.053810119628906, lon=-122.8106460571289, alt=108, tz=-8.0, dst='A'),
#  Row(faa='0W3', name='Harford County Airport', lat=39.566837310791016, lon=-76.20240020751953, alt=409, tz=-5.0, dst='A'),
#  Row(faa='10C', name='Galt Field Airport', lat=42.402889251708984, lon=-88.37511444091797, alt=875, tz=-6.0, dst='U'),
#  Row(faa='17G', name='Port Bucyrus-Crawford County Airport', lat=40.78155517578125, lon=-82.97480773925781, alt=1003, tz=-5.0, dst='A'),
#  Row(faa='19A', name='Jackson County Airport', lat=34.175865173339844, lon=-83.56159973144531, alt=951, tz=-4.0, dst='U'),
#  Row(faa='1A3', name='Martin Campbell Field Airport', lat=35.015804290771484, lon=-84.34683227539062, alt=1789, tz=-4.0, dst='A'),
#  Row(faa='1B9', name='Mansfield Municipal', lat=42.0001335144043, lon=-71.19676971435547, alt=122, tz=-5.0, dst='A'),
#  Row(faa='1C9', name='Frazier Lake Airpark', lat=54.01333236694336, lon=-124.7683334350586, alt=152, tz=-8.0, dst='A'),
#  Row(faa='1CS', name='Clow International Airport', lat=41.69597625732422, lon=-88.12923431396484, alt=670, tz=-6.0, dst='U'),
#  Row(faa='1G3', name='Kent State Airport', lat=41.151390075683594, lon=-81.41510772705078, alt=1134, tz=-4.0, dst='A'),
#  Row(faa='1OH', name='Fortman Airport', lat=40.55532455444336, lon=-84.3866195678711, alt=885, tz=-5.0, dst='U'),
#  Row(faa='1RL', name='Point Roberts Airpark', lat=48.97972106933594, lon=-123.07888793945312, alt=10, tz=-7.0, dst='A'),
#  Row(faa='24C', name='Lowell City Airport', lat=42.95391845703125, lon=-85.34390258789062, alt=681, tz=-5.0, dst='A'),
#  Row(faa='24J', name='Suwannee County Airport', lat=30.300125122070312, lon=-83.02469635009766, alt=104, tz=-5.0, dst='A'),
#  Row(faa='25D', name='Forest Lake Airport', lat=45.247745513916016, lon=-92.994384765625, alt=925, tz=-5.0, dst='A'),
#  Row(faa='29D', name='Grove City Airport', lat=41.146026611328125, lon=-80.1677474975586, alt=1371, tz=-5.0, dst='A'),
#  Row(faa='2A0', name='Mark Anton Airport', lat=35.48625183105469, lon=-84.93108367919922, alt=718, tz=-4.0, dst='A'),
#  Row(faa='2G2', name='Jefferson County Airpark', lat=40.3602180480957, lon=-80.70087432861328, alt=1196, tz=-4.0, dst='A'),
#  Row(faa='2G9', name='Somerset County Airport', lat=40.03887176513672, lon=-79.0149917602539, alt=2275, tz=-5.0, dst='A'),
#  Row(faa='2J9', name='Quincy Municipal Airport', lat=30.597869873046875, lon=-84.55742645263672, alt=225, tz=-5.0, dst='A'),
#  Row(faa='369', name='Atmautluak Airport', lat=60.866668701171875, lon=-162.27305603027344, alt=18, tz=-10.0, dst='A'),
#  Row(faa='36U', name='Heber City Municipal Airport', lat=40.48180389404297, lon=-111.42880249023438, alt=5637, tz=-6.0, dst='A'),
#  Row(faa='38W', name='Lynden Airport', lat=48.955894470214844, lon=-122.45811462402344, alt=106, tz=-8.0, dst='A'),
#  Row(faa='3D2', name='Ephraim-Gibraltar Airport', lat=45.13541793823242, lon=-87.18794250488281, alt=773, tz=-5.0, dst='A'),
#  Row(faa='3G3', name='Wadsworth Municipal', lat=41.00315856933594, lon=-81.75643920898438, alt=974, tz=-5.0, dst='A'),
#  Row(faa='3G4', name='Ashland County Airport', lat=40.90297317504883, lon=-82.2556381225586, alt=1206, tz=-5.0, dst='A'),
#  Row(faa='3J1', name='Ridgeland Airport', lat=32.49341583251953, lon=-80.99175262451172, alt=79, tz=-5.0, dst='A'),
#  Row(faa='3W2', name='Put-in-Bay Airport', lat=41.35210037231445, lon=-82.49700164794922, alt=595, tz=-6.0, dst='A'),
#  Row(faa='40J', name='Perry-Foley Airport', lat=30.069278717041016, lon=-83.58058166503906, alt=44, tz=-5.0, dst='A'),
#  Row(faa='41N', name='Braceville Airport', lat=41.21116638183594, lon=-80.96925354003906, alt=900, tz=-5.0, dst='A'),
#  Row(faa='47A', name='Cherokee County Airport', lat=34.312217712402344, lon=-84.42215728759766, alt=1219, tz=-4.0, dst='A'),
#  Row(faa='49A', name='Gilmer County Airport', lat=34.62822341918945, lon=-84.52658081054688, alt=1486, tz=-4.0, dst='A'),
#  Row(faa='49X', name='Chemehuevi Valley', lat=34.52888870239258, lon=-114.43196868896484, alt=638, tz=-8.0, dst='A'),
#  Row(faa='4A4', name='Polk County Airport - Cornelius Moore Field', lat=34.01869583129883, lon=-85.14646911621094, alt=974, tz=-4.0, dst='A'),
#  Row(faa='4A7', name='Clayton County Tara Field', lat=33.38909912109375, lon=-84.3323974609375, alt=874, tz=-5.0, dst='A'),
#  Row(faa='4A9', name='Isbell Field Airport', lat=34.47369384765625, lon=-85.72138977050781, alt=877, tz=-5.0, dst='A'),
#  Row(faa='4B8', name='Robertson Field', lat=41.689334869384766, lon=-72.86469268798828, alt=202, tz=-5.0, dst='A'),
#  Row(faa='4G0', name='Pittsburgh-Monroeville Airport', lat=40.452640533447266, lon=-79.77491760253906, alt=1187, tz=-5.0, dst='A'),
#  Row(faa='4G2', name='Hamburg Inc Airport', lat=42.70089340209961, lon=-78.91475677490234, alt=751, tz=-5.0, dst='A'),
#  Row(faa='4G4', name='Youngstown Elser Metro Airport', lat=40.961795806884766, lon=-80.67733001708984, alt=1070, tz=-5.0, dst='A'),
#  Row(faa='4I7', name='Putnam County Airport', lat=39.6335563659668, lon=-86.81380462646484, alt=842, tz=-5.0, dst='U'),
#  Row(faa='4U9', name='Dell Flight Strip', lat=44.735748291015625, lon=-112.72001647949219, alt=6007, tz=-7.0, dst='A'),
#  Row(faa='52A', name='Madison GA Municipal Airport', lat=33.612125396728516, lon=-83.46044158935547, alt=694, tz=-5.0, dst='A'),
#  Row(faa='54J', name='DeFuniak Springs Airport', lat=30.731111526489258, lon=-86.15377807617188, alt=289, tz=-5.0, dst='A'),
#  Row(faa='55J', name='Fernandina Beach Municipal Airport', lat=30.611833572387695, lon=-81.46119689941406, alt=16, tz=-4.0, dst='A'),
#  Row(faa='57C', name='East Troy Municipal Airport', lat=42.79716491699219, lon=-88.37261199951172, alt=860, tz=-6.0, dst='A'),
#  Row(faa='60J', name='Ocean Isle Beach Airport', lat=33.908504486083984, lon=-78.4366683959961, alt=32, tz=-5.0, dst='U'),
#  Row(faa='6A2', name='Griffin-Spalding County Airport', lat=33.22697067260742, lon=-84.27494812011719, alt=958, tz=-5.0, dst='A'),
#  Row(faa='6K8', name='Tok Junction Airport', lat=63.329444885253906, lon=-142.95361328125, alt=1639, tz=-9.0, dst='A'),
#  Row(faa='6S0', name='Big Timber Airport', lat=45.80638885498047, lon=-109.98110961914062, alt=4492, tz=-7.0, dst='A'),
#  Row(faa='6S2', name='Florence', lat=43.982818603515625, lon=-124.11136627197266, alt=51, tz=-7.0, dst='A'),
#  Row(faa='6Y8', name='Welke Airport', lat=45.72111129760742, lon=-85.52027893066406, alt=664, tz=-5.0, dst='A'),
#  Row(faa='70J', name='Cairo-Grady County Airport', lat=30.887977600097656, lon=-84.15473175048828, alt=265, tz=-5.0, dst='A'),
#  Row(faa='70N', name='Spring Hill Airport', lat=41.34735870361328, lon=-75.4158935546875, alt=1729, tz=-5.0, dst='A'),
#  Row(faa='7A4', name='Foster Field', lat=42.46644592285156, lon=-90.16938781738281, alt=990, tz=-6.0, dst='A'),
#  Row(faa='7D9', name='Germack Airport', lat=41.77783203125, lon=-80.90397644042969, alt=820, tz=-5.0, dst='A'),
#  Row(faa='7N7', name='Spitfire Aerodrome', lat=39.735565185546875, lon=-75.39772033691406, alt=40, tz=-5.0, dst='A'),
#  Row(faa='8M8', name='Garland Airport', lat=44.80652618408203, lon=-84.27619171142578, alt=1218, tz=-5.0, dst='A'),
#  Row(faa='93C', name='Richland Airport', lat=43.283355712890625, lon=-90.29827880859375, alt=742, tz=-6.0, dst='A'),
#  Row(faa='99N', name='Bamberg County Airport', lat=33.304527282714844, lon=-81.10841369628906, alt=231, tz=-5.0, dst='A'),
#  Row(faa='9A1', name='Covington Municipal Airport', lat=33.63230895996094, lon=-83.84745025634766, alt=809, tz=-4.0, dst='A'),
#  Row(faa='9A5', name='Barwick Lafayette Airport', lat=34.688480377197266, lon=-85.29032897949219, alt=777, tz=-4.0, dst='A'),
#  Row(faa='A39', name='Phoenix Regional Airport', lat=32.99169921875, lon=-111.9209976196289, alt=1300, tz=-7.0, dst='A'),
#  Row(faa='AAF', name='Apalachicola Regional Airport', lat=29.72760581970215, lon=-85.0274429321289, alt=20, tz=-6.0, dst='A'),
#  Row(faa='ABE', name='Lehigh Valley Intl', lat=40.65208435058594, lon=-75.44080352783203, alt=393, tz=-5.0, dst='A'),
#  Row(faa='ABI', name='Abilene Rgnl', lat=32.411319732666016, lon=-99.68190002441406, alt=1791, tz=-6.0, dst='A'),
#  Row(faa='ABL', name='Ambler Airport', lat=67.10639190673828, lon=-157.8574981689453, alt=334, tz=-9.0, dst='A'),
#  Row(faa='ABQ', name='Albuquerque International Sunport', lat=35.04022216796875, lon=-106.60919189453125, alt=5355, tz=-7.0, dst='A'),
#  Row(faa='ABR', name='Aberdeen Regional Airport', lat=45.449100494384766, lon=-98.42179870605469, alt=1302, tz=-6.0, dst='A'),
#  Row(faa='ABY', name='Southwest Georgia Regional Airport', lat=31.535499572753906, lon=-84.19450378417969, alt=197, tz=-5.0, dst='A'),
#  Row(faa='ACK', name='Nantucket Mem', lat=41.2530517578125, lon=-70.0601806640625, alt=48, tz=-5.0, dst='A'),
#  Row(faa='ACT', name='Waco Rgnl', lat=31.61128807067871, lon=-97.23052215576172, alt=516, tz=-6.0, dst='A'),
#  Row(faa='ACV', name='Arcata', lat=40.978111267089844, lon=-124.10861206054688, alt=221, tz=-8.0, dst='A'),
#  Row(faa='ACY', name='Atlantic City Intl', lat=39.457584381103516, lon=-74.57716369628906, alt=75, tz=-5.0, dst='A'),
#  Row(faa='ADK', name='Adak Airport', lat=51.87799835205078, lon=-176.64599609375, alt=18, tz=-10.0, dst='A'),
#  Row(faa='ADM', name='Ardmore Muni', lat=34.30083465576172, lon=-97.0088882446289, alt=762, tz=-6.0, dst='A'),
#  Row(faa='ADQ', name='Kodiak', lat=57.74996566772461, lon=-152.4938507080078, alt=78, tz=-9.0, dst='A'),
#  Row(faa='ADS', name='Addison', lat=32.96855926513672, lon=-96.8364486694336, alt=644, tz=-5.0, dst='A'),
#  Row(faa='ADW', name='Andrews Afb', lat=38.81080627441406, lon=-76.86702728271484, alt=280, tz=-5.0, dst='A'),
#  Row(faa='AET', name='Allakaket Airport', lat=66.5519027709961, lon=-152.6221923828125, alt=441, tz=-8.0, dst='A'),
#  Row(faa='AEX', name='Alexandria Intl', lat=31.32740020751953, lon=-92.54983520507812, alt=89, tz=-6.0, dst='A'),
#  Row(faa='AFE', name='Kake Airport', lat=56.961387634277344, lon=-133.9102783203125, alt=172, tz=-9.0, dst='A'),
#  Row(faa='AFW', name='Fort Worth Alliance Airport', lat=32.98777770996094, lon=-97.31888580322266, alt=722, tz=-6.0, dst='A'),
#  Row(faa='AGC', name='Allegheny County Airport', lat=40.354400634765625, lon=-79.9301986694336, alt=1252, tz=-5.0, dst='A'),
#  Row(faa='AGN', name='Angoon Seaplane Base', lat=57.50361251831055, lon=-134.5850067138672, alt=0, tz=-9.0, dst='A'),
#  Row(faa='AGS', name='Augusta Rgnl At Bush Fld', lat=33.36994552612305, lon=-81.9645004272461, alt=144, tz=-5.0, dst='A'),
#  Row(faa='AHN', name='Athens Ben Epps Airport', lat=33.94860076904297, lon=-83.32630157470703, alt=808, tz=-5.0, dst='A'),
#  Row(faa='AIA', name='Alliance Municipal Airport', lat=42.0533332824707, lon=-102.80388641357422, alt=3931, tz=-7.0, dst='A'),
#  Row(faa='AIK', name='Municipal Airport', lat=33.64938735961914, lon=-81.68502807617188, alt=529, tz=-5.0, dst='A'),
#  Row(faa='AIN', name='Wainwright Airport', lat=70.63805389404297, lon=-159.99472045898438, alt=41, tz=-9.0, dst='A'),
#  Row(faa='AIZ', name='Lee C Fine Memorial Airport', lat=38.09603500366211, lon=-92.54948425292969, alt=869, tz=-5.0, dst='A'),
#  Row(faa='AKB', name='Atka Airport', lat=52.220279693603516, lon=-174.20639038085938, alt=56, tz=-9.0, dst='A'),
#  Row(faa='AKC', name='Akron Fulton Intl', lat=41.037498474121094, lon=-81.4669189453125, alt=1067, tz=-5.0, dst='A'),
#  Row(faa='AKI', name='Akiak Airport', lat=60.90277862548828, lon=-161.23056030273438, alt=30, tz=-9.0, dst='A'),
#  Row(faa='AKK', name='Akhiok Airport', lat=56.9386100769043, lon=-154.1824951171875, alt=44, tz=-9.0, dst='A'),
#  Row(faa='AKN', name='King Salmon', lat=58.67677688598633, lon=-156.64927673339844, alt=68, tz=-9.0, dst='A'),
#  Row(faa='AKP', name='Anaktuvuk Pass Airport', lat=68.13359832763672, lon=-151.7429962158203, alt=2103, tz=-9.0, dst='A'),
#  Row(faa='ALB', name='Albany Intl', lat=42.748268127441406, lon=-73.80168914794922, alt=285, tz=-5.0, dst='A'),
#  Row(faa='ALI', name='Alice Intl', lat=27.740888595581055, lon=-98.02694702148438, alt=178, tz=-6.0, dst='A'),
#  Row(faa='ALM', name='Alamogordo White Sands Regional Airport', lat=32.839900970458984, lon=-105.99099731445312, alt=4200, tz=-7.0, dst='A'),
#  Row(faa='ALO', name='Waterloo Regional Airport', lat=42.557098388671875, lon=-92.40029907226562, alt=873, tz=-6.0, dst='A'),
#  Row(faa='ALS', name='San Luis Valley Regional Airport', lat=37.435001373291016, lon=-105.86666870117188, alt=7539, tz=-7.0, dst='A'),
#  Row(faa='ALW', name='Walla Walla Regional Airport', lat=46.09489822387695, lon=-118.28800201416016, alt=1191, tz=-8.0, dst='A'),
#  Row(faa='ALX', name='Alexandria', lat=38.80634689331055, lon=-77.06210327148438, alt=1, tz=-5.0, dst='A'),
#  Row(faa='ALZ', name='Alitak Seaplane Base', lat=56.899444580078125, lon=-154.24777221679688, alt=0, tz=-9.0, dst='A'),
#  Row(faa='AMA', name='Rick Husband Amarillo Intl', lat=35.21936798095703, lon=-101.7059326171875, alt=3607, tz=-6.0, dst='A'),
#  Row(faa='ANB', name='Anniston Metro', lat=33.588165283203125, lon=-85.85810852050781, alt=612, tz=-6.0, dst='A'),
#  Row(faa='ANC', name='Ted Stevens Anchorage Intl', lat=61.17436218261719, lon=-149.99636840820312, alt=152, tz=-9.0, dst='A'),
#  Row(faa='AND', name='Anderson Rgnl', lat=34.49458312988281, lon=-82.70938873291016, alt=782, tz=-5.0, dst='A'),
#  Row(faa='ANI', name='Aniak Airport', lat=61.581600189208984, lon=-159.54299926757812, alt=88, tz=-9.0, dst='A'),
#  Row(faa='ANN', name='Annette Island', lat=55.04243469238281, lon=-131.57223510742188, alt=119, tz=-9.0, dst='A'),
#  Row(faa='ANP', name='Lee Airport', lat=38.942779541015625, lon=-76.5683364868164, alt=34, tz=-5.0, dst='A'),
#  Row(faa='ANQ', name='Tri-State Steuben County Airport', lat=41.63969802856445, lon=-85.08349609375, alt=995, tz=-5.0, dst='A'),
#  Row(faa='ANV', name='Anvik Airport', lat=62.64670181274414, lon=-160.1909942626953, alt=309, tz=-9.0, dst='A'),
#  Row(faa='AOH', name='Lima Allen County Airport', lat=40.70747756958008, lon=-84.0270767211914, alt=975, tz=-5.0, dst='A'),
#  Row(faa='AOO', name='Altoona Blair Co', lat=40.29637145996094, lon=-78.32002258300781, alt=1504, tz=-5.0, dst='A'),
#  Row(faa='AOS', name='Amook Bay Seaplane Base', lat=57.47138977050781, lon=-153.81527709960938, alt=0, tz=-9.0, dst='A'),
#  Row(faa='APA', name='Centennial', lat=39.57012939453125, lon=-104.84929656982422, alt=5883, tz=-7.0, dst='A'),
#  Row(faa='APC', name='Napa County Airport', lat=38.21319580078125, lon=-122.28069305419922, alt=35, tz=-7.0, dst='A'),
#  Row(faa='APF', name='Naples Muni', lat=26.152618408203125, lon=-81.7752914428711, alt=8, tz=-5.0, dst='A'),
#  Row(faa='APG', name='Phillips Aaf', lat=39.46622085571289, lon=-76.16880798339844, alt=57, tz=-5.0, dst='A'),
#  Row(faa='APN', name='Alpena County Regional Airport', lat=45.07809829711914, lon=-83.560302734375, alt=689, tz=-5.0, dst='A'),
#  Row(faa='AQC', name='Klawock Seaplane Base', lat=55.554656982421875, lon=-133.10169982910156, alt=0, tz=-9.0, dst='A'),
#  Row(faa='ARA', name='Acadiana Rgnl', lat=30.037757873535156, lon=-91.88389587402344, alt=24, tz=-6.0, dst='A'),
#  Row(faa='ARB', name='Ann Arbor Municipal Airport', lat=42.13227462768555, lon=-83.44441986083984, alt=839, tz=-5.0, dst='A'),
#  Row(faa='ARC', name='Arctic Village Airport', lat=68.11470031738281, lon=-145.57899475097656, alt=2092, tz=-9.0, dst='A'),
#  Row(faa='ART', name='Watertown Intl', lat=43.991920471191406, lon=-76.02173614501953, alt=325, tz=-5.0, dst='A'),
#  Row(faa='ARV', name='Lakeland', lat=45.92777633666992, lon=-89.7308349609375, alt=1629, tz=-6.0, dst='A'),
#  Row(faa='ASE', name='Aspen Pitkin County Sardy Field', lat=39.223201751708984, lon=-106.86900329589844, alt=7820, tz=-7.0, dst='A'),
#  Row(faa='ASH', name='Boire Field Airport', lat=42.7817497253418, lon=-71.51477813720703, alt=199, tz=-4.0, dst='A'),
#  Row(faa='AST', name='Astoria Regional Airport', lat=46.1579704284668, lon=-123.87869262695312, alt=15, tz=-8.0, dst='A'),
#  Row(faa='ATK', name='Atqasuk Edward Burnell Sr Memorial Airport', lat=70.46730041503906, lon=-157.43600463867188, alt=96, tz=-9.0, dst='A'),
#  Row(faa='ATL', name='Hartsfield Jackson Atlanta Intl', lat=33.63671875, lon=-84.42807006835938, alt=1026, tz=-5.0, dst='A'),
#  Row(faa='ATT', name='Camp Mabry Austin City', lat=30.316659927368164, lon=-97.7666015625, alt=0, tz=-6.0, dst='A'),
#  Row(faa='ATW', name='Appleton', lat=44.25752639770508, lon=-88.50757598876953, alt=680, tz=-6.0, dst='A'),
#  Row(faa='ATY', name='Watertown Regional Airport', lat=44.91400146484375, lon=-97.15470123291016, alt=1748, tz=-6.0, dst='A'),
#  Row(faa='AUG', name='Augusta State', lat=44.320648193359375, lon=-69.79731750488281, alt=352, tz=-5.0, dst='A'),
#  Row(faa='AUK', name='Alakanuk Airport', lat=62.68000030517578, lon=-164.66000366210938, alt=10, tz=-9.0, dst='A'),
#  Row(faa='AUS', name='Austin Bergstrom Intl', lat=30.194528579711914, lon=-97.66989135742188, alt=542, tz=-6.0, dst='A'),
#  Row(faa='AUW', name='Wausau Downtown Airport', lat=44.92628479003906, lon=-89.62699890136719, alt=1201, tz=-6.0, dst='U'),
#  Row(faa='AVL', name='Asheville Regional Airport', lat=35.436195373535156, lon=-82.54180908203125, alt=2165, tz=-5.0, dst='A'),
#  Row(faa='AVO', name='Executive', lat=27.591388702392578, lon=-81.52889251708984, alt=160, tz=-5.0, dst='A'),
#  Row(faa='AVP', name='Wilkes Barre Scranton Intl', lat=41.338478088378906, lon=-75.72340393066406, alt=962, tz=-5.0, dst='A'),
#  Row(faa='AVW', name='Marana Regional', lat=32.4095573425293, lon=-111.21839141845703, alt=2031, tz=-7.0, dst='U'),
#  Row(faa='AVX', name='Avalon', lat=33.404998779296875, lon=-118.41583251953125, alt=1602, tz=-8.0, dst='A'),
#  Row(faa='AZA', name='Phoenix-Mesa Gateway', lat=33.30783462524414, lon=-111.65499877929688, alt=1382, tz=-7.0, dst='N'),
#  Row(faa='AZO', name='Kalamazoo', lat=42.2348747253418, lon=-85.55205535888672, alt=874, tz=-5.0, dst='A'),
#  Row(faa='BAB', name='Beale Afb', lat=39.13608932495117, lon=-121.43656921386719, alt=113, tz=-8.0, dst='A'),
#  Row(faa='BAD', name='Barksdale Afb', lat=32.5018196105957, lon=-93.66267395019531, alt=166, tz=-6.0, dst='A'),
#  Row(faa='BAF', name='Barnes Municipal', lat=42.1579475402832, lon=-72.71587371826172, alt=270, tz=-4.0, dst='A'),
#  Row(faa='BBX', name='Wings Field', lat=40.13750076293945, lon=-75.26499938964844, alt=302, tz=-5.0, dst='A'),
#  Row(faa='BCE', name='Bryce Canyon', lat=37.706443786621094, lon=-112.14580535888672, alt=7590, tz=-7.0, dst='A'),
#  Row(faa='BCT', name='Boca Raton', lat=26.37849998474121, lon=-80.10769653320312, alt=13, tz=-5.0, dst='A'),
#  Row(faa='BDE', name='Baudette Intl', lat=48.72844314575195, lon=-94.61222076416016, alt=1086, tz=-6.0, dst='A'),
#  Row(faa='BDL', name='Bradley Intl', lat=41.93888854980469, lon=-72.68321990966797, alt=173, tz=-5.0, dst='A'),
#  Row(faa='BDR', name='Igor I Sikorsky Mem', lat=41.16347122192383, lon=-73.12616729736328, alt=9, tz=-5.0, dst='A'),
#  Row(faa='BEC', name='Beech Factory Airport', lat=37.69391632080078, lon=-97.21492004394531, alt=1409, tz=-5.0, dst='A'),
#  Row(faa='BED', name='Laurence G Hanscom Fld', lat=42.46995162963867, lon=-71.28903198242188, alt=133, tz=-5.0, dst='A'),
#  Row(faa='BEH', name='Southwest Michigan Regional Airport', lat=42.12858200073242, lon=-86.42849731445312, alt=643, tz=-5.0, dst='A'),
#  Row(faa='BET', name='Bethel', lat=60.77977752685547, lon=-161.83799743652344, alt=121, tz=-9.0, dst='A'),
#  Row(faa='BFD', name='Bradford Regional Airport', lat=41.8031005859375, lon=-78.64009857177734, alt=2143, tz=-5.0, dst='A'),
#  Row(faa='BFF', name='Western Nebraska Regional Airport', lat=41.874000549316406, lon=-103.59600067138672, alt=3967, tz=-7.0, dst='A'),
#  Row(faa='BFI', name='Boeing Fld King Co Intl', lat=47.529998779296875, lon=-122.30194854736328, alt=21, tz=-8.0, dst='A'),
#  Row(faa='BFL', name='Meadows Fld', lat=35.433597564697266, lon=-119.05677032470703, alt=507, tz=-8.0, dst='A'),
#  Row(faa='BFM', name='Mobile Downtown', lat=30.62678337097168, lon=-88.0680923461914, alt=26, tz=-6.0, dst='A'),
#  Row(faa='BFP', name='Beaver Falls', lat=40.7724723815918, lon=-80.39144134521484, alt=1253, tz=-4.0, dst='A'),
#  Row(faa='BFT', name='Beaufort', lat=32.47740936279297, lon=-80.72315979003906, alt=37, tz=-5.0, dst='A'),
#  Row(faa='BFT', name='BFT County Airport', lat=32.410831451416016, lon=-80.63500213623047, alt=500, tz=-5.0, dst='A'),
#  Row(faa='BGE', name='Decatur County Industrial Air Park', lat=30.97159767150879, lon=-84.63692474365234, alt=141, tz=-5.0, dst='A'),
#  Row(faa='BGM', name='Greater Binghamton Edwin A Link Fld', lat=42.20869064331055, lon=-75.9798355102539, alt=1636, tz=-5.0, dst='A'),
#  Row(faa='BGR', name='Bangor Intl', lat=44.80744552612305, lon=-68.82814025878906, alt=192, tz=-5.0, dst='A'),
#  Row(faa='BHB', name='Hancock County - Bar Harbor', lat=44.44976806640625, lon=-68.36156463623047, alt=83, tz=-5.0, dst='A'),
#  Row(faa='BHM', name='Birmingham Intl', lat=33.56294250488281, lon=-86.75354766845703, alt=644, tz=-6.0, dst='A'),
#  Row(faa='BID', name='Block Island State Airport', lat=41.16805648803711, lon=-71.5777816772461, alt=108, tz=-5.0, dst='A'),
#  Row(faa='BIF', name='Biggs Aaf', lat=31.84952735900879, lon=-106.38003540039062, alt=3948, tz=-7.0, dst='A'),
#  Row(faa='BIG', name='Allen Aaf', lat=63.99454879760742, lon=-145.72164916992188, alt=1291, tz=-9.0, dst='A'),
#  Row(faa='BIL', name='Billings Logan International Airport', lat=45.80921173095703, lon=-108.53765106201172, alt=3652, tz=-7.0, dst='A'),
#  Row(faa='BIS', name='Bismarck Municipal Airport', lat=46.775840759277344, lon=-100.7579345703125, alt=1661, tz=-6.0, dst='A'),
#  Row(faa='BIV', name='Tulip City Airport', lat=42.74277877807617, lon=-86.10783386230469, alt=698, tz=-5.0, dst='A'),
#  Row(faa='BIX', name='Keesler Afb', lat=30.410425186157227, lon=-88.92443084716797, alt=33, tz=-6.0, dst='A'),
#  Row(faa='BJC', name='Rocky Mountain Metropolitan Airport', lat=39.90888977050781, lon=-105.11722564697266, alt=5670, tz=-7.0, dst='A'),
#  Row(faa='BJI', name='Bemidji Regional Airport', lat=47.51072311401367, lon=-94.93472290039062, alt=1391, tz=-6.0, dst='A'),
#  Row(faa='BKC', name='Buckland Airport', lat=65.9816665649414, lon=-161.149169921875, alt=31, tz=-9.0, dst='A'),
#  Row(faa='BKD', name='Stephens Co', lat=32.71904754638672, lon=-98.89099884033203, alt=1284, tz=-6.0, dst='A'),
#  Row(faa='BKF', name='Buckley Afb', lat=39.70166778564453, lon=-104.75166320800781, alt=5662, tz=-7.0, dst='A'),
#  Row(faa='BKG', name='Branson LLC', lat=36.5319938659668, lon=-93.20055389404297, alt=1302, tz=-6.0, dst='A'),
#  Row(faa='BKH', name='Barking Sands Pmrf', lat=22.0228328704834, lon=-159.78500366210938, alt=23, tz=-10.0, dst='A'),
#  Row(faa='BKL', name='Burke Lakefront Airport', lat=41.51750183105469, lon=-81.68333435058594, alt=583, tz=-5.0, dst='A'),
#  Row(faa='BKW', name='Raleigh County Memorial Airport', lat=37.78730010986328, lon=-81.12419891357422, alt=2504, tz=-5.0, dst='A'),
#  Row(faa='BKX', name='Brookings Regional Airport', lat=44.3047981262207, lon=-96.81690216064453, alt=1648, tz=-6.0, dst='A'),
#  Row(faa='BLD', name='Boulder City Municipal Airport', lat=35.565101623535156, lon=-114.51399993896484, alt=2201, tz=-8.0, dst='U'),
#  Row(faa='BLF', name='Mercer County Airport', lat=37.295799255371094, lon=-81.20770263671875, alt=2857, tz=-5.0, dst='A'),
#  Row(faa='BLH', name='Blythe Airport', lat=33.61916732788086, lon=-114.71688842773438, alt=399, tz=-8.0, dst='A'),
#  Row(faa='BLI', name='Bellingham Intl', lat=48.792694091796875, lon=-122.53752899169922, alt=170, tz=-8.0, dst='A'),
#  Row(faa='BLV', name='Scott Afb Midamerica', lat=38.5451774597168, lon=-89.8351821899414, alt=459, tz=-6.0, dst='A'),
#  Row(faa='BMC', name='Brigham City', lat=41.551998138427734, lon=-112.06199645996094, alt=4229, tz=-7.0, dst='A'),
#  Row(faa='BMG', name='Monroe County Airport', lat=39.146018981933594, lon=-86.61668395996094, alt=846, tz=-5.0, dst='A'),
#  Row(faa='BMI', name='Central Illinois Rgnl', lat=40.47711181640625, lon=-88.9159164428711, alt=871, tz=-6.0, dst='A'),
#  Row(faa='BMX', name='Big Mountain Afs', lat=59.36124801635742, lon=-155.25881958007812, alt=663, tz=-9.0, dst='A'),
#  Row(faa='BNA', name='Nashville Intl', lat=36.124473571777344, lon=-86.67819213867188, alt=599, tz=-6.0, dst='A'),
#  Row(faa='BOI', name='Boise Air Terminal', lat=43.564361572265625, lon=-116.22286224365234, alt=2871, tz=-7.0, dst='A'),
#  Row(faa='BOS', name='General Edward Lawrence Logan Intl', lat=42.36434555053711, lon=-71.00518035888672, alt=19, tz=-5.0, dst='A'),
#  Row(faa='BOW', name='Bartow Municipal Airport', lat=27.94339942932129, lon=-81.78340148925781, alt=125, tz=-6.0, dst='U'),
#  Row(faa='BPT', name='Southeast Texas Rgnl', lat=29.95083236694336, lon=-94.02069091796875, alt=15, tz=-6.0, dst='A'),
#  Row(faa='BQK', name='Brunswick Golden Isles Airport', lat=31.258800506591797, lon=-81.46649932861328, alt=26, tz=-5.0, dst='A'),
#  Row(faa='BRD', name='Brainerd Lakes Rgnl', lat=46.39830780029297, lon=-94.13807678222656, alt=1226, tz=-6.0, dst='U'),
#  Row(faa='BRL', name='Southeast Iowa Regional Airport', lat=40.783199310302734, lon=-91.12550354003906, alt=698, tz=-6.0, dst='A'),
#  Row(faa='BRO', name='Brownsville South Padre Island Intl', lat=25.90683364868164, lon=-97.42585754394531, alt=22, tz=-6.0, dst='A'),
#  Row(faa='BRW', name='Wiley Post Will Rogers Mem', lat=71.28544616699219, lon=-156.76600646972656, alt=44, tz=-9.0, dst='A'),
#  Row(faa='BSF', name='Bradshaw Aaf', lat=19.760055541992188, lon=-155.5537109375, alt=6190, tz=-10.0, dst='A'),
#  Row(faa='BTI', name='Barter Island Lrrs', lat=70.13398742675781, lon=-143.5818634033203, alt=2, tz=-9.0, dst='A'),
#  Row(faa='BTM', name='Bert Mooney Airport', lat=45.95480728149414, lon=-112.49747467041016, alt=5550, tz=-7.0, dst='A'),
#  Row(faa='BTR', name='Baton Rouge Metro Ryan Fld', lat=30.533166885375977, lon=-91.1496353149414, alt=70, tz=-6.0, dst='A'),
#  Row(faa='BTT', name='Bettles', lat=66.9139404296875, lon=-151.529052734375, alt=644, tz=-9.0, dst='A'),
#  Row(faa='BTV', name='Burlington Intl', lat=44.47186279296875, lon=-73.15327453613281, alt=335, tz=-5.0, dst='A'),
#  Row(faa='BUF', name='Buffalo Niagara Intl', lat=42.94052505493164, lon=-78.73217010498047, alt=724, tz=-5.0, dst='A'),
#  Row(faa='BUR', name='Bob Hope', lat=34.20066833496094, lon=-118.3586654663086, alt=778, tz=-8.0, dst='A'),
#  Row(faa='BUU', name='Municipal Airport', lat=42.69071578979492, lon=-88.30467987060547, alt=780, tz=-6.0, dst='A'),
#  Row(faa='BUY', name='Burlington-Alamance Regional Airport', lat=36.04854202270508, lon=-79.47489166259766, alt=617, tz=-4.0, dst='A'),
#  Row(faa='BVY', name='Beverly Municipal Airport', lat=42.58414077758789, lon=-70.91614532470703, alt=107, tz=-5.0, dst='A'),
#  Row(faa='BWD', name='KBWD', lat=31.793611526489258, lon=-98.95649719238281, alt=1387, tz=-6.0, dst='A'),
#  Row(faa='BWG', name='Bowling Green-Warren County Regional Airport', lat=36.96452713012695, lon=-86.41967010498047, alt=547, tz=-5.0, dst='A'),
#  Row(faa='BWI', name='Baltimore Washington Intl', lat=39.17536163330078, lon=-76.6683349609375, alt=146, tz=-5.0, dst='A'),
#  Row(faa='BXK', name='Buckeye Municipal Airport', lat=33.42041778564453, lon=-112.6861801147461, alt=1033, tz=-7.0, dst='U'),
#  Row(faa='BXS', name='Borrego Valley Airport', lat=33.259029388427734, lon=-116.32096862792969, alt=520, tz=-7.0, dst='A'),
#  Row(faa='BYH', name='Arkansas Intl', lat=35.96434783935547, lon=-89.94395446777344, alt=254, tz=-6.0, dst='A'),
#  Row(faa='BYS', name='Bicycle Lake Aaf', lat=35.28053283691406, lon=-116.6300277709961, alt=2350, tz=-8.0, dst='A'),
#  Row(faa='BYW', name='Blakely Island Airport', lat=48.56024932861328, lon=-122.80242919921875, alt=0, tz=-8.0, dst='A'),
#  Row(faa='BZN', name='Gallatin Field', lat=45.77764129638672, lon=-111.16014862060547, alt=4500, tz=-7.0, dst='A'),
#  Row(faa='C02', name='Grand Geneva Resort Airport', lat=42.61491775512695, lon=-88.38957977294922, alt=835, tz=-6.0, dst='U'),
#  Row(faa='C16', name='Frasca Field', lat=40.14497756958008, lon=-88.2001953125, alt=735, tz=-6.0, dst='A'),
#  Row(faa='C47', name='Portage Municipal Airport', lat=43.5603141784668, lon=-89.48286437988281, alt=825, tz=-6.0, dst='U'),
#  Row(faa='C65', name='Plymouth Municipal Airport', lat=41.36513137817383, lon=-86.30025482177734, alt=800, tz=-5.0, dst='A'),
#  Row(faa='C89', name='Sylvania Airport', lat=42.703250885009766, lon=-87.95896911621094, alt=785, tz=-6.0, dst='A'),
#  Row(faa='C91', name='Dowagiac Municipal Airport', lat=41.99293518066406, lon=-86.12801361083984, alt=748, tz=-5.0, dst='U'),
#  Row(faa='CAE', name='Columbia Metropolitan', lat=33.9388313293457, lon=-81.1195297241211, alt=236, tz=-5.0, dst='A'),
#  Row(faa='CAK', name='Akron Canton Regional Airport', lat=40.91608428955078, lon=-81.44219207763672, alt=1228, tz=-5.0, dst='A'),
#  Row(faa='CAR', name='Caribou Muni', lat=46.871498107910156, lon=-68.01791381835938, alt=626, tz=-4.0, dst='A'),
#  Row(faa='CBE', name='Greater Cumberland Rgnl.', lat=39.61527633666992, lon=-78.76055908203125, alt=775, tz=-5.0, dst='A'),
#  Row(faa='CBM', name='Columbus Afb', lat=33.64383316040039, lon=-88.44383239746094, alt=219, tz=-6.0, dst='A'),
#  Row(faa='CCO', name='Coweta County Airport', lat=33.31156539916992, lon=-84.7697525024414, alt=970, tz=-5.0, dst='A'),
#  Row(faa='CCR', name='Buchanan Field Airport', lat=37.98966598510742, lon=-122.05689239501953, alt=26, tz=-8.0, dst='A'),
#  Row(faa='CDB', name='Cold Bay', lat=55.20606231689453, lon=-162.72543334960938, alt=96, tz=-9.0, dst='A'),
#  Row(faa='CDC', name='Cedar City Rgnl', lat=37.700965881347656, lon=-113.09884643554688, alt=5622, tz=-7.0, dst='A'),
#  Row(faa='CDI', name='Cambridge Municipal Airport', lat=39.97502899169922, lon=-81.57758331298828, alt=799, tz=-5.0, dst='U'),
#  Row(faa='CDK', name='CedarKey', lat=29.13422203063965, lon=-83.05046844482422, alt=11, tz=-4.0, dst='A'),
#  Row(faa='CDN', name='Woodward Field', lat=34.28358459472656, lon=-80.56485748291016, alt=302, tz=-5.0, dst='A'),
#  Row(faa='CDR', name='Chadron Municipal Airport', lat=42.837501525878906, lon=-103.0955581665039, alt=3297, tz=-7.0, dst='A'),
#  Row(faa='CDS', name='Childress Muni', lat=34.433780670166016, lon=-100.28799438476562, alt=1954, tz=-6.0, dst='A'),
#  Row(faa='CDV', name='Merle K Mudhole Smith', lat=60.49177932739258, lon=-145.47755432128906, alt=48, tz=-9.0, dst='A'),
#  Row(faa='CDW', name='Caldwell Essex County Airport', lat=40.875221252441406, lon=-74.28136444091797, alt=172, tz=-5.0, dst='A'),
#  Row(faa='CEC', name='Del Norte County Airport', lat=41.78020095825195, lon=-124.23699951171875, alt=57, tz=-8.0, dst='A'),
#  Row(faa='CEF', name='Westover Arb Metropolitan', lat=42.19401550292969, lon=-72.53478240966797, alt=241, tz=-5.0, dst='A'),
#  Row(faa='CEM', name='Central Airport', lat=65.57389068603516, lon=-144.7808380126953, alt=937, tz=-9.0, dst='A'),
#  Row(faa='CEU', name='Clemson', lat=34.67222213745117, lon=-82.8858871459961, alt=891, tz=-4.0, dst='A'),
#  Row(faa='CEW', name='Bob Sikes', lat=30.778833389282227, lon=-86.52210998535156, alt=213, tz=-6.0, dst='A'),
#  Row(faa='CEZ', name='Cortez Muni', lat=37.303001403808594, lon=-108.62805938720703, alt=5918, tz=-7.0, dst='A'),
#  Row(faa='CFD', name='Coulter Fld', lat=30.715694427490234, lon=-96.33135986328125, alt=367, tz=-6.0, dst='A'),
#  Row(faa='CGA', name='Craig Seaplane Base', lat=55.47888946533203, lon=-133.1477813720703, alt=0, tz=-9.0, dst='A'),
#  Row(faa='CGF', name='Cuyahoga County', lat=41.56512451171875, lon=-81.48635864257812, alt=879, tz=-5.0, dst='A'),
#  Row(faa='CGI', name='Cape Girardeau Regional Airport', lat=37.22529983520508, lon=-89.57080078125, alt=342, tz=-6.0, dst='A'),
#  Row(faa='CGX', name='Meigs Field', lat=41.86027908325195, lon=-87.6097183227539, alt=585, tz=-6.0, dst='A'),
#  Row(faa='CGZ', name='Casa Grande Municipal Airport', lat=32.95488739013672, lon=-111.76683044433594, alt=1464, tz=-7.0, dst='U'),
#  Row(faa='CHA', name='Lovell Fld', lat=35.0352783203125, lon=-85.20381164550781, alt=683, tz=-5.0, dst='A'),
#  Row(faa='CHI', name='All Airports', lat=41.883609771728516, lon=-87.63166809082031, alt=596, tz=-6.0, dst='A'),
#  Row(faa='CHO', name='Charlottesville-Albemarle', lat=38.13863754272461, lon=-78.4528579711914, alt=639, tz=-5.0, dst='A'),
#  Row(faa='CHS', name='Charleston Afb Intl', lat=32.89864730834961, lon=-80.04052734375, alt=45, tz=-5.0, dst='A'),
#  Row(faa='CHU', name='Chuathbaluk Airport', lat=61.579166412353516, lon=-159.21556091308594, alt=243, tz=-9.0, dst='A'),
#  Row(faa='CIC', name='Chico Muni', lat=39.79538345336914, lon=-121.8584213256836, alt=238, tz=-8.0, dst='A'),
#  Row(faa='CID', name='Cedar Rapids', lat=41.88469314575195, lon=-91.71080780029297, alt=869, tz=-6.0, dst='A'),
#  Row(faa='CIK', name='Chalkyitsik Airport', lat=66.6449966430664, lon=-143.74000549316406, alt=544, tz=-9.0, dst='A'),
#  Row(faa='CIL', name='Council Airport', lat=64.89778137207031, lon=-163.70333862304688, alt=85, tz=-9.0, dst='A'),
#  Row(faa='CIU', name='Chippewa County International Airport', lat=46.25080108642578, lon=-84.47239685058594, alt=800, tz=-5.0, dst='A'),
#  Row(faa='CKB', name='Harrison Marion Regional Airport', lat=39.296600341796875, lon=-80.22810363769531, alt=1217, tz=-5.0, dst='A'),
#  Row(faa='CKD', name='Crooked Creek Airport', lat=61.86777877807617, lon=-158.13499450683594, alt=178, tz=-9.0, dst='A'),
#  Row(faa='CKF', name='Crisp County Cordele Airport', lat=31.988832473754883, lon=-83.77391815185547, alt=310, tz=-5.0, dst='A'),
#  Row(faa='CKV', name='Clarksville-Montgomery County Regional Airport', lat=36.621944427490234, lon=-87.41500091552734, alt=550, tz=-5.0, dst='A'),
#  Row(faa='CLC', name='Clear Lake Metroport', lat=29.556900024414062, lon=-95.13749694824219, alt=35, tz=6.0, dst='A'),
#  Row(faa='CLD', name='McClellan-Palomar Airport', lat=33.07419967651367, lon=-117.16480255126953, alt=328, tz=-8.0, dst='A'),
#  Row(faa='CLE', name='Cleveland Hopkins Intl', lat=41.41168975830078, lon=-81.84979248046875, alt=791, tz=-5.0, dst='A'),
#  Row(faa='CLL', name='Easterwood Fld', lat=30.58858299255371, lon=-96.36383056640625, alt=321, tz=-6.0, dst='A'),
#  Row(faa='CLM', name='William R Fairchild International Airport', lat=48.120201110839844, lon=-123.5, alt=291, tz=-8.0, dst='A'),
#  Row(faa='CLT', name='Charlotte Douglas Intl', lat=35.2140007019043, lon=-80.9431381225586, alt=748, tz=-5.0, dst='A'),
#  Row(faa='CLW', name='Clearwater Air Park', lat=27.976472854614258, lon=-82.7586669921875, alt=70, tz=-5.0, dst='A'),
#  Row(faa='CMH', name='Port Columbus Intl', lat=39.99797058105469, lon=-82.89189147949219, alt=815, tz=-5.0, dst='A'),
#  Row(faa='CMI', name='Champaign', lat=40.039249420166016, lon=-88.2780532836914, alt=754, tz=-6.0, dst='A'),
#  Row(faa='CMX', name='Houghton County Memorial Airport', lat=47.168399810791016, lon=-88.48909759521484, alt=1095, tz=-5.0, dst='A'),
#  Row(faa='CNM', name='Cavern City Air Terminal', lat=32.33747100830078, lon=-104.26327514648438, alt=3295, tz=-7.0, dst='A'),
#  Row(faa='CNW', name='Tstc Waco', lat=31.63783073425293, lon=-97.07414245605469, alt=470, tz=-6.0, dst='A'),
#  Row(faa='CNY', name='Canyonlands Field', lat=38.755001068115234, lon=-109.75472259521484, alt=4555, tz=-7.0, dst='A'),
#  Row(faa='COD', name='Yellowstone Rgnl', lat=44.52019500732422, lon=-109.0238037109375, alt=5102, tz=-7.0, dst='A'),
#  Row(faa='COF', name='Patrick Afb', lat=28.234922409057617, lon=-80.61012268066406, alt=8, tz=-5.0, dst='A'),
#  Row(faa='CON', name='Concord Municipal', lat=43.20267105102539, lon=-71.50232696533203, alt=342, tz=-5.0, dst='A'),
#  Row(faa='COS', name='City Of Colorado Springs Muni', lat=38.80580520629883, lon=-104.70077514648438, alt=6187, tz=-7.0, dst='A'),
#  Row(faa='COT', name='Cotulla Lasalle Co', lat=28.456693649291992, lon=-99.22029113769531, alt=474, tz=-6.0, dst='A'),
#  Row(faa='COU', name='Columbia Rgnl', lat=38.818092346191406, lon=-92.2196273803711, alt=889, tz=-6.0, dst='A'),
#  Row(faa='CPR', name='Natrona Co Intl', lat=42.90800094604492, lon=-106.46441650390625, alt=5347, tz=-7.0, dst='A'),
#  Row(faa='CPS', name='St. Louis Downtown Airport', lat=38.57072448730469, lon=-90.15621948242188, alt=413, tz=-6.0, dst='U'),
#  Row(faa='CRE', name='Grand Strand Airport', lat=33.81174850463867, lon=-78.72394561767578, alt=31, tz=-4.0, dst='A'),
#  Row(faa='CRP', name='Corpus Christi Intl', lat=27.770360946655273, lon=-97.501220703125, alt=44, tz=-6.0, dst='A'),
#  Row(faa='CRW', name='Yeager', lat=38.373146057128906, lon=-81.59318542480469, alt=981, tz=-5.0, dst='A'),
#  Row(faa='CSG', name='Columbus Metropolitan Airport', lat=32.516334533691406, lon=-84.93885803222656, alt=397, tz=-5.0, dst='A'),
#  Row(faa='CTB', name='Cut Bank Muni', lat=48.60835266113281, lon=-112.37614440917969, alt=3854, tz=-7.0, dst='A'),
#  Row(faa='CTH', name='Chester County G O Carlson Airport', lat=39.97890090942383, lon=-75.86540222167969, alt=660, tz=-5.0, dst='A'),
#  Row(faa='CTJ', name='West Georgia Regional Airport - O V Gray Field', lat=33.63169479370117, lon=-85.15226745605469, alt=1165, tz=-4.0, dst='A'),
#  Row(faa='CTY', name='Cross City', lat=29.635528564453125, lon=-83.10475158691406, alt=42, tz=-4.0, dst='A'),
#  Row(faa='CVG', name='Cincinnati Northern Kentucky Intl', lat=39.04883575439453, lon=-84.6678237915039, alt=896, tz=-5.0, dst='A'),
#  Row(faa='CVN', name='Clovis Muni', lat=34.425140380859375, lon=-103.07927703857422, alt=4216, tz=-6.0, dst='A'),
#  Row(faa='CVS', name='Cannon Afb', lat=34.382774353027344, lon=-103.3221435546875, alt=4295, tz=-7.0, dst='A'),
#  Row(faa='CVX', name='Charlevoix Municipal Airport', lat=45.304779052734375, lon=-85.27532958984375, alt=669, tz=-5.0, dst='A'),
#  Row(faa='CWA', name='Central Wisconsin', lat=44.77272415161133, lon=-89.64663696289062, alt=840, tz=-6.0, dst='A'),
#  Row(faa='CWI', name='Clinton Municipal', lat=41.83074951171875, lon=-90.32897186279297, alt=708, tz=-6.0, dst='A'),
#  Row(faa='CXF', name='Coldfoot Airport', lat=67.25138854980469, lon=-150.17611694335938, alt=1014, tz=-9.0, dst='A'),
#  Row(faa='CXL', name='Calexico Intl', lat=32.66950225830078, lon=-115.5133285522461, alt=4, tz=-8.0, dst='A'),
#  Row(faa='CXO', name='Lone Star Executive', lat=30.35183334350586, lon=-95.41446685791016, alt=245, tz=-6.0, dst='A'),
#  Row(faa='CXY', name='Capital City Airport', lat=40.217140197753906, lon=-76.85136413574219, alt=347, tz=-5.0, dst='A'),
#  Row(faa='CYF', name='Chefornak Airport', lat=60.149166107177734, lon=-164.28555297851562, alt=40, tz=-9.0, dst='A'),
#  Row(faa='CYM', name='Chatham Seaplane Base', lat=57.51499938964844, lon=-134.94610595703125, alt=0, tz=-9.0, dst='A'),
#  Row(faa='CYS', name='Cheyenne Rgnl Jerry Olson Fld', lat=41.155723571777344, lon=-104.81183624267578, alt=6156, tz=-7.0, dst='A'),
#  Row(faa='CYT', name='Yakataga Airport', lat=60.08190155029297, lon=-142.4936065673828, alt=12, tz=-9.0, dst='A'),
#  Row(faa='CZF', name='Cape Romanzof Lrrs', lat=61.780296325683594, lon=-166.0387420654297, alt=457, tz=-9.0, dst='A'),
#  Row(faa='CZN', name='Chisana Airport', lat=62.071109771728516, lon=-142.04833984375, alt=1011, tz=-9.0, dst='A'),
#  Row(faa='DAB', name='Daytona Beach Intl', lat=29.179916381835938, lon=-81.05805969238281, alt=34, tz=-5.0, dst='A'),
#  Row(faa='DAL', name='Dallas Love Fld', lat=32.847110748291016, lon=-96.85177612304688, alt=487, tz=-6.0, dst='A'),
#  Row(faa='DAY', name='James M Cox Dayton Intl', lat=39.902374267578125, lon=-84.21937561035156, alt=1009, tz=-5.0, dst='A'),
#  Row(faa='DBQ', name='Dubuque Rgnl', lat=42.402000427246094, lon=-90.70947265625, alt=1076, tz=-6.0, dst='A'),
#  Row(faa='DCA', name='Ronald Reagan Washington Natl', lat=38.852081298828125, lon=-77.0377197265625, alt=15, tz=-5.0, dst='A'),
#  Row(faa='DDC', name='Dodge City Regional Airport', lat=37.76340103149414, lon=-99.9655990600586, alt=2594, tz=-6.0, dst='A'),
#  Row(faa='DEC', name='Decatur', lat=39.834564208984375, lon=-88.86569213867188, alt=682, tz=-6.0, dst='A'),
#  Row(faa='DEN', name='Denver Intl', lat=39.861656188964844, lon=-104.67317962646484, alt=5431, tz=-7.0, dst='A'),
#  Row(faa='DET', name='Coleman A Young Muni', lat=42.40919494628906, lon=-83.0098648071289, alt=626, tz=-5.0, dst='A'),
#  Row(faa='DFW', name='Dallas Fort Worth Intl', lat=32.896827697753906, lon=-97.03799438476562, alt=607, tz=-6.0, dst='A'),
#  Row(faa='DGL', name='Douglas Municipal Airport', lat=31.34260368347168, lon=-109.50645446777344, alt=4173, tz=-7.0, dst='N'),
#  Row(faa='DHN', name='Dothan Rgnl', lat=31.321338653564453, lon=-85.44963073730469, alt=401, tz=-6.0, dst='A'),
#  Row(faa='DHT', name='Dalhart Muni', lat=36.022586822509766, lon=-102.54727935791016, alt=3991, tz=-6.0, dst='A'),
#  Row(faa='DIK', name='Dickinson Theodore Roosevelt Regional Airport', lat=46.79750061035156, lon=-102.80194091796875, alt=2592, tz=-5.0, dst='A'),
#  Row(faa='DKB', name='De Kalb Taylor Municipal Airport', lat=41.933834075927734, lon=-88.7056884765625, alt=914, tz=-6.0, dst='U'),
#  Row(faa='DKK', name='Chautauqua County-Dunkirk Airport', lat=42.49333572387695, lon=-79.27204132080078, alt=693, tz=-5.0, dst='A'),
#  Row(faa='DKX', name='Knoxville Downtown Island Airport', lat=35.96383285522461, lon=-83.87366485595703, alt=833, tz=-4.0, dst='A'),
#  Row(faa='DLF', name='Laughlin Afb', lat=29.359485626220703, lon=-100.7779769897461, alt=1082, tz=-6.0, dst='A'),
#  Row(faa='DLG', name='Dillingham', lat=59.0446662902832, lon=-158.5054931640625, alt=74, tz=-9.0, dst='A'),
#  Row(faa='DLH', name='Duluth Intl', lat=46.84209060668945, lon=-92.19364929199219, alt=1428, tz=-6.0, dst='A'),
#  Row(faa='DLL', name='Baraboo Wisconsin Dells Airport', lat=43.521785736083984, lon=-89.77092742919922, alt=979, tz=-6.0, dst='A'),
#  Row(faa='DMA', name='Davis Monthan Afb', lat=32.166465759277344, lon=-110.88314056396484, alt=2704, tz=-7.0, dst='A'),
#  Row(faa='DNL', name='Daniel Field Airport', lat=33.46650314331055, lon=-82.03938293457031, alt=423, tz=-5.0, dst='A'),
#  Row(faa='DNN', name='Dalton Municipal Airport', lat=34.72294616699219, lon=-84.87024688720703, alt=709, tz=-4.0, dst='A'),
#  Row(faa='DOV', name='Dover Afb', lat=39.129539489746094, lon=-75.46595764160156, alt=28, tz=-5.0, dst='A'),
#  Row(faa='DPA', name='Dupage', lat=41.907779693603516, lon=-88.24861145019531, alt=758, tz=-6.0, dst='A'),
#  Row(faa='DQH', name='Douglas Municipal Airport', lat=31.47673797607422, lon=-82.86056518554688, alt=257, tz=-5.0, dst='A'),
#  Row(faa='DRG', name='Deering Airport', lat=66.0696029663086, lon=-162.76600646972656, alt=21, tz=-9.0, dst='A'),
#  Row(faa='DRI', name='Beauregard Rgnl', lat=30.831722259521484, lon=-93.33992004394531, alt=202, tz=-6.0, dst='A'),
#  Row(faa='DRM', name='Drummond Island Airport', lat=46.00931167602539, lon=-83.74393463134766, alt=668, tz=-5.0, dst='A'),
#  Row(faa='DRO', name='Durango La Plata Co', lat=37.15151596069336, lon=-107.75376892089844, alt=6685, tz=-7.0, dst='A'),
#  Row(faa='DRT', name='Del Rio Intl', lat=29.374208450317383, lon=-100.92715454101562, alt=1002, tz=-6.0, dst='A'),
#  Row(faa='DSM', name='Des Moines Intl', lat=41.533973693847656, lon=-93.6630859375, alt=958, tz=-6.0, dst='A'),
#  Row(faa='DTA', name='Delta Municipal Airport', lat=39.380638122558594, lon=-112.5077133178711, alt=4759, tz=-6.0, dst='A'),
#  Row(faa='DTS', name='Destin', lat=30.400060653686523, lon=-86.47147369384766, alt=23, tz=-5.0, dst='A'),
#  Row(faa='DTW', name='Detroit Metro Wayne Co', lat=42.21244430541992, lon=-83.35338592529297, alt=645, tz=-5.0, dst='A'),
#  Row(faa='DUC', name='Halliburton Field Airport', lat=34.47130584716797, lon=-97.9598617553711, alt=1114, tz=-6.0, dst='A'),
#  Row(faa='DUG', name='Bisbee Douglas Intl', lat=31.46902847290039, lon=-109.60366821289062, alt=4154, tz=-7.0, dst='A'),
#  Row(faa='DUJ', name='DuBois Regional Airport', lat=41.17829895019531, lon=-78.89869689941406, alt=1817, tz=-5.0, dst='A'),
#  Row(faa='DUT', name='Unalaska', lat=53.90013885498047, lon=-166.5435028076172, alt=22, tz=-9.0, dst='A'),
#  Row(faa='DVL', name='Devils Lake Regional Airport', lat=48.114444732666016, lon=-98.90860748291016, alt=1445, tz=-6.0, dst='A'),
#  Row(faa='DVT', name='Deer Valley Municipal Airport', lat=33.41170120239258, lon=112.45700073242188, alt=1478, tz=-7.0, dst='A'),
#  Row(faa='DWA', name='Yolo County Airport', lat=38.57938766479492, lon=-121.85694122314453, alt=100, tz=-7.0, dst='A'),
#  Row(faa='DWH', name='David Wayne Hooks Field', lat=30.063745498657227, lon=-95.55427551269531, alt=152, tz=-6.0, dst='A'),
#  Row(faa='DWS', name='Orlando', lat=28.398000717163086, lon=-81.56999969482422, alt=340, tz=-5.0, dst='A'),
#  Row(faa='DXR', name='Danbury Municipal Airport', lat=41.37153625488281, lon=-73.48219299316406, alt=458, tz=-5.0, dst='A'),
#  Row(faa='DYS', name='Dyess Afb', lat=32.42075729370117, lon=-99.85459899902344, alt=1789, tz=-6.0, dst='A'),
#  Row(faa='E25', name='Wickenburg Municipal Airport', lat=33.96889877319336, lon=-112.79900360107422, alt=2377, tz=-7.0, dst='A'),
#  Row(faa='E51', name='Bagdad Airport', lat=34.59585189819336, lon=-113.17019653320312, alt=4183, tz=-7.0, dst='A'),
#  Row(faa='E55', name='Ocean Ridge Airport', lat=38.801612854003906, lon=-123.5306396484375, alt=940, tz=-8.0, dst='A'),
#  Row(faa='E63', name='Gila Bend Municipal Airport', lat=32.96017074584961, lon=-112.67363739013672, alt=789, tz=-7.0, dst='U'),
#  Row(faa='E91', name='Chinle Municipal Airport', lat=36.11088180541992, lon=-109.57542419433594, alt=5547, tz=-7.0, dst='N'),
#  Row(faa='EAA', name='Eagle Airport', lat=64.7780532836914, lon=-141.14971923828125, alt=908, tz=-9.0, dst='A'),
#  Row(faa='EAR', name='Kearney Municipal Airport', lat=40.72700119018555, lon=-99.00679779052734, alt=2131, tz=-6.0, dst='A'),
#  Row(faa='EAT', name='Pangborn Field', lat=47.39799880981445, lon=-120.20600128173828, alt=1249, tz=-8.0, dst='A'),
#  Row(faa='EAU', name='Chippewa Valley Regional Airport', lat=44.86579895019531, lon=-91.48429870605469, alt=913, tz=-6.0, dst='A'),
#  Row(faa='ECA', name='Iosco County', lat=44.31100082397461, lon=-83.4219970703125, alt=606, tz=-5.0, dst='A'),
#  Row(faa='ECG', name='Elizabeth City Cgas Rgnl', lat=36.260581970214844, lon=-76.17457580566406, alt=12, tz=-5.0, dst='A'),
#  Row(faa='ECP', name='Panama City-NW Florida Bea.', lat=30.341699600219727, lon=-85.79730224609375, alt=69, tz=-6.0, dst='A'),
#  Row(faa='EDF', name='Elmendorf Afb', lat=61.25098419189453, lon=-149.80650329589844, alt=212, tz=-9.0, dst='A'),
#  Row(faa='EDW', name='Edwards Afb', lat=34.905418395996094, lon=-117.88373565673828, alt=2302, tz=-8.0, dst='A'),
#  Row(faa='EEK', name='Eek Airport', lat=60.2136116027832, lon=-162.04388427734375, alt=15, tz=-9.0, dst='A'),
#  Row(faa='EEN', name='Dillant Hopkins Airport', lat=72.27083587646484, lon=42.89833450317383, alt=149, tz=-5.0, dst='A'),
#  Row(faa='EET', name='Shelby County Airport', lat=33.17777633666992, lon=-86.7832260131836, alt=586, tz=-6.0, dst='A'),
#  Row(faa='EFD', name='Ellington Fld', lat=29.607332229614258, lon=-95.15875244140625, alt=32, tz=-6.0, dst='A'),
#  Row(faa='EGA', name='Eagle County Airport', lat=39.64276123046875, lon=-106.91593170166016, alt=6548, tz=-7.0, dst='U'),
# ...
#  Row(faa='MPB', name='Miami Seaplane Base', lat=25.77829933166504, lon=-80.17030334472656, alt=0, tz=-5.0, dst='A'),
#  Row(faa='MPI', name='MariposaYosemite', lat=37.30390167236328, lon=-120.02220153808594, alt=2454, tz=-8.0, dst='A'),
#  Row(faa='MPV', name='Edward F Knapp State', lat=44.2035026550293, lon=-72.56232452392578, alt=1165, tz=-5.0, dst='A'),
#  Row(faa='MQB', name='Macomb Municipal Airport', lat=40.520084381103516, lon=-90.65238952636719, alt=707, tz=-6.0, dst='U'),
#  Row(faa='MQT', name='Sawyer International Airport', lat=46.35361099243164, lon=-87.39527893066406, alt=1221, tz=-5.0, dst='A'),
#  Row(faa='MRB', name='Eastern WV Regional Airport', lat=39.240699768066406, lon=-77.59100341796875, alt=554, tz=-5.0, dst='A'),
#  Row(faa='MRI', name='Merrill Fld', lat=61.21354293823242, lon=-149.84445190429688, alt=137, tz=-9.0, dst='A'),
#  Row(faa='MRK', name='Marco Islands', lat=25.995027542114258, lon=-81.67253112792969, alt=5, tz=-5.0, dst='A'),
#  Row(faa='MRN', name='Foothills Regional Airport', lat=35.82023239135742, lon=-81.61151123046875, alt=1270, tz=-4.0, dst='A'),
#  Row(faa='MRY', name='Monterey Peninsula', lat=36.58700180053711, lon=-121.84294128417969, alt=257, tz=-8.0, dst='A'),
#  Row(faa='MSL', name='Northwest Alabama Regional Airport', lat=34.74530029296875, lon=-87.61019897460938, alt=550, tz=-6.0, dst='A'),
#  Row(faa='MSN', name='Dane Co Rgnl Truax Fld', lat=43.13985824584961, lon=-89.33751678466797, alt=887, tz=-6.0, dst='A'),
#  Row(faa='MSO', name='Missoula Intl', lat=46.91630554199219, lon=-114.0905532836914, alt=3205, tz=-7.0, dst='A'),
#  Row(faa='MSP', name='Minneapolis St Paul Intl', lat=44.881954193115234, lon=-93.22176361083984, alt=841, tz=-6.0, dst='A'),
#  Row(faa='MSS', name='Massena Intl Richards Fld', lat=44.93583297729492, lon=-74.84555053710938, alt=215, tz=-5.0, dst='A'),
#  Row(faa='MSY', name='Louis Armstrong New Orleans Intl', lat=29.993389129638672, lon=-90.25802612304688, alt=4, tz=-6.0, dst='A'),
#  Row(faa='MTC', name='Selfridge Angb', lat=42.608333587646484, lon=-82.83550262451172, alt=580, tz=-5.0, dst='A'),
#  Row(faa='MTH', name='Florida Keys Marathon Airport', lat=24.726110458374023, lon=-81.0513916015625, alt=7, tz=-5.0, dst='A'),
#  Row(faa='MTJ', name='Montrose Regional Airport', lat=38.50979232788086, lon=-107.89424133300781, alt=5759, tz=-7.0, dst='A'),
#  Row(faa='MTM', name='Metlakatla Seaplane Base', lat=55.13111114501953, lon=-131.5780487060547, alt=0, tz=-9.0, dst='A'),
#  Row(faa='MUE', name='Waimea Kohala', lat=20.001327514648438, lon=-155.66810607910156, alt=2671, tz=-10.0, dst='A'),
#  Row(faa='MUI', name='Muir Aaf', lat=40.434810638427734, lon=-76.56941223144531, alt=489, tz=-5.0, dst='A'),
#  Row(faa='MUO', name='Mountain Home Afb', lat=43.043601989746094, lon=-115.87242889404297, alt=2996, tz=-7.0, dst='A'),
#  Row(faa='MVL', name='Morrisville Stowe State Airport', lat=44.53499984741211, lon=-72.61399841308594, alt=732, tz=-5.0, dst='A'),
#  Row(faa='MVY', name="Martha\\'s Vineyard", lat=41.391666412353516, lon=-70.61528015136719, alt=67, tz=-5.0, dst='A'),
#  Row(faa='MWA', name='Williamson Country Regional Airport', lat=37.75495529174805, lon=-89.01109313964844, alt=472, tz=-5.0, dst='A'),
#  Row(faa='MWC', name='Lawrence J Timmerman Airport', lat=43.110389709472656, lon=-88.03441619873047, alt=745, tz=-6.0, dst='A'),
#  Row(faa='MWH', name='Grant Co Intl', lat=47.207706451416016, lon=-119.3201904296875, alt=1185, tz=-8.0, dst='A'),
#  Row(faa='MWL', name='Mineral Wells', lat=32.7816047668457, lon=-98.06017303466797, alt=974, tz=-6.0, dst='A'),
#  Row(faa='MWM', name='Windom Municipal Airport', lat=43.91340255737305, lon=-95.10940551757812, alt=1410, tz=-6.0, dst='A'),
#  Row(faa='MXF', name='Maxwell Afb', lat=32.38294219970703, lon=-86.36577606201172, alt=171, tz=-6.0, dst='A'),
#  Row(faa='MXY', name='McCarthy Airport', lat=61.43706130981445, lon=-142.903076171875, alt=1531, tz=-8.0, dst='U'),
#  Row(faa='MYF', name='Montgomery Field', lat=32.47589874267578, lon=117.75900268554688, alt=17, tz=-8.0, dst='A'),
#  Row(faa='MYL', name='McCall Municipal Airport', lat=44.88972091674805, lon=-116.10138702392578, alt=5021, tz=-7.0, dst='A'),
#  Row(faa='MYR', name='Myrtle Beach Intl', lat=33.67974853515625, lon=-78.92832946777344, alt=25, tz=-5.0, dst='A'),
#  Row(faa='MYU', name='Mekoryuk Airport', lat=60.37139892578125, lon=-166.27099609375, alt=48, tz=-9.0, dst='A'),
#  Row(faa='MYV', name='Yuba County Airport', lat=39.055301666259766, lon=-121.34110260009766, alt=62, tz=-8.0, dst='A'),
#  Row(faa='MZJ', name='Pinal Airpark', lat=32.50972366333008, lon=-111.32527923583984, alt=1893, tz=-7.0, dst='N'),
#  Row(faa='N53', name='Stroudsburg-Pocono Airport', lat=41.03587341308594, lon=-75.16068267822266, alt=480, tz=-5.0, dst='A'),
#  Row(faa='N69', name='Stormville Airport', lat=41.576969146728516, lon=-73.73235321044922, alt=358, tz=-5.0, dst='A'),
#  Row(faa='N87', name='Trenton-Robbinsville Airport', lat=40.21394348144531, lon=-74.60177612304688, alt=118, tz=-5.0, dst='A'),
#  Row(faa='NBG', name='New Orleans Nas Jrb', lat=29.825332641601562, lon=-90.03500366210938, alt=3, tz=-6.0, dst='A'),
#  Row(faa='NBU', name='Naval Air Station', lat=42.09055709838867, lon=-87.82250213623047, alt=653, tz=-6.0, dst='A'),
#  Row(faa='NCN', name='Chenega Bay Airport', lat=60.07722091674805, lon=-147.991943359375, alt=72, tz=-9.0, dst='A'),
#  Row(faa='NEL', name='Lakehurst Naes', lat=40.03333282470703, lon=-74.35333251953125, alt=103, tz=-5.0, dst='A'),
#  Row(faa='NFL', name='Fallon Nas', lat=39.41658401489258, lon=-118.70098114013672, alt=3934, tz=-8.0, dst='A'),
#  Row(faa='NGF', name='Kaneohe Bay Mcaf', lat=21.45045280456543, lon=-157.76800537109375, alt=24, tz=-10.0, dst='A'),
#  Row(faa='NGP', name='Corpus Christi NAS', lat=27.69270133972168, lon=-97.29037475585938, alt=18, tz=-6.0, dst='A'),
#  Row(faa='NGU', name='Norfolk Ns', lat=36.937644958496094, lon=-76.28929138183594, alt=15, tz=-5.0, dst='A'),
#  Row(faa='NGZ', name='NAS Alameda', lat=37.78609848022461, lon=-122.318603515625, alt=10, tz=-9.0, dst='U'),
#  Row(faa='NHK', name='Patuxent River Nas', lat=38.285980224609375, lon=-76.41178131103516, alt=39, tz=-5.0, dst='A'),
#  Row(faa='NIB', name='Nikolai Airport', lat=63.010833740234375, lon=-154.38389587402344, alt=427, tz=-9.0, dst='A'),
#  Row(faa='NID', name='China Lake Naws', lat=35.685420989990234, lon=-117.6920394897461, alt=2283, tz=-8.0, dst='A'),
#  Row(faa='NIP', name='Jacksonville Nas', lat=30.2358341217041, lon=-81.68055725097656, alt=22, tz=-5.0, dst='A'),
#  Row(faa='NJK', name='El Centro Naf', lat=32.8292236328125, lon=-115.67166900634766, alt=-42, tz=-8.0, dst='A'),
#  Row(faa='NKT', name='Cherry Point Mcas', lat=34.90087127685547, lon=-76.88072967529297, alt=29, tz=-5.0, dst='A'),
#  Row(faa='NKX', name='Miramar Mcas', lat=32.86769485473633, lon=-117.1417465209961, alt=478, tz=-8.0, dst='A'),
#  Row(faa='NLC', name='Lemoore Nas', lat=36.333011627197266, lon=-119.95207977294922, alt=234, tz=-8.0, dst='A'),
#  Row(faa='NLG', name='Nelson Lagoon', lat=56.00749969482422, lon=-161.1602783203125, alt=14, tz=-9.0, dst='A'),
#  Row(faa='NME', name='Nightmute Airport', lat=60.47111129760742, lon=-164.70083618164062, alt=4, tz=-10.0, dst='A'),
#  Row(faa='NMM', name='Meridian Nas', lat=32.55208206176758, lon=-88.55555725097656, alt=317, tz=-6.0, dst='A'),
#  Row(faa='NNL', name='Nondalton Airport', lat=59.96694564819336, lon=-154.85166931152344, alt=262, tz=-9.0, dst='A'),
#  Row(faa='NOW', name='Port Angeles Cgas', lat=48.1414794921875, lon=-123.41407775878906, alt=13, tz=-8.0, dst='A'),
#  Row(faa='NPA', name='Pensacola Nas', lat=30.3526554107666, lon=-87.31864929199219, alt=28, tz=-6.0, dst='A'),
#  Row(faa='NPZ', name='Porter County Municipal Airport', lat=41.45397186279297, lon=-87.007080078125, alt=770, tz=-6.0, dst='A'),
#  Row(faa='NQA', name='Millington Rgnl Jetport', lat=35.356666564941406, lon=-89.87027740478516, alt=320, tz=-6.0, dst='A'),
#  Row(faa='NQI', name='Kingsville Nas', lat=27.50722312927246, lon=-97.80972290039062, alt=50, tz=-6.0, dst='A'),
#  Row(faa='NQX', name='Key West Nas', lat=24.575834274291992, lon=-81.68888854980469, alt=6, tz=-5.0, dst='A'),
#  Row(faa='NSE', name='Whiting Fld Nas North', lat=30.724166870117188, lon=-87.02194213867188, alt=199, tz=-6.0, dst='A'),
#  Row(faa='NTD', name='Point Mugu Nas', lat=34.12028503417969, lon=-119.12094116210938, alt=13, tz=-8.0, dst='A'),
#  Row(faa='NTU', name='Oceana Nas', lat=36.820701599121094, lon=-76.03353881835938, alt=22, tz=-5.0, dst='A'),
#  Row(faa='NUI', name='Nuiqsut Airport', lat=70.20999908447266, lon=-151.00555419921875, alt=38, tz=-9.0, dst='A'),
#  Row(faa='NUL', name='Nulato Airport', lat=64.72944641113281, lon=-158.0741729736328, alt=399, tz=-9.0, dst='A'),
#  Row(faa='NUP', name='Nunapitchuk Airport', lat=60.90583419799805, lon=-162.4391632080078, alt=12, tz=-9.0, dst='A'),
#  Row(faa='NUQ', name='Moffett Federal Afld', lat=37.416141510009766, lon=-122.04914093017578, alt=32, tz=-8.0, dst='A'),
#  Row(faa='NUW', name='Whidbey Island Nas', lat=48.351802825927734, lon=-122.6559066772461, alt=47, tz=-8.0, dst='A'),
#  Row(faa='NXP', name='Twentynine Palms Eaf', lat=34.29616165161133, lon=-116.16220092773438, alt=2051, tz=-8.0, dst='A'),
#  Row(faa='NXX', name='Willow Grove Nas Jrb', lat=40.199832916259766, lon=-75.1481704711914, alt=358, tz=-5.0, dst='A'),
#  Row(faa='NY9', name='Long Lake', lat=43.97506332397461, lon=-74.42044067382812, alt=1629, tz=5.0, dst='A'),
#  Row(faa='NYC', name='All Airports', lat=40.714168548583984, lon=-74.0058364868164, alt=31, tz=-5.0, dst='A'),
#  Row(faa='NYG', name='Quantico Mcaf', lat=38.50168228149414, lon=-77.30533599853516, alt=11, tz=-5.0, dst='A'),
#  Row(faa='NZC', name='Cecil Field', lat=30.218700408935547, lon=-81.87670135498047, alt=81, tz=-5.0, dst='A'),
#  Row(faa='NZJ', name='El Toro', lat=33.67613220214844, lon=-117.73116302490234, alt=383, tz=-8.0, dst='A'),
#  Row(faa='NZY', name='North Island Nas', lat=32.69921875, lon=-117.2153091430664, alt=26, tz=-8.0, dst='A'),
#  Row(faa='O03', name='Morgantown Airport', lat=40.157039642333984, lon=-75.87049102783203, alt=600, tz=-5.0, dst='A'),
#  Row(faa='O27', name='Oakdale Airport', lat=37.75633239746094, lon=-120.8001937866211, alt=237, tz=-8.0, dst='A'),
#  Row(faa='OAJ', name='Albert J Ellis', lat=34.82916259765625, lon=-77.61213684082031, alt=94, tz=-5.0, dst='A'),
#  Row(faa='OAK', name='Metropolitan Oakland Intl', lat=37.72127914428711, lon=-122.22071838378906, alt=9, tz=-8.0, dst='A'),
#  Row(faa='OAR', name='Marina Muni', lat=36.68187713623047, lon=-121.76234436035156, alt=134, tz=-8.0, dst='A'),
#  Row(faa='OBE', name='County', lat=27.265832901000977, lon=-80.85111236572266, alt=34, tz=-5.0, dst='A'),
#  Row(faa='OBU', name='Kobuk Airport', lat=66.91222381591797, lon=-156.897216796875, alt=137, tz=-9.0, dst='A'),
#  Row(faa='OCA', name='Key Largo', lat=25.325393676757812, lon=-80.27477264404297, alt=8, tz=-5.0, dst='A'),
#  Row(faa='OCF', name='International Airport', lat=29.172500610351562, lon=-82.22416687011719, alt=89, tz=-5.0, dst='A'),
#  Row(faa='OEB', name='Branch County Memorial Airport', lat=41.933570861816406, lon=-85.05229187011719, alt=959, tz=-5.0, dst='A'),
#  Row(faa='OFF', name='Offutt Afb', lat=41.11833190917969, lon=-95.91251373291016, alt=1052, tz=-6.0, dst='A'),
#  Row(faa='OGG', name='Kahului', lat=20.898649215698242, lon=-156.43045043945312, alt=54, tz=-10.0, dst='N'),
#  Row(faa='OGS', name='Ogdensburg Intl', lat=44.681854248046875, lon=-75.46549987792969, alt=297, tz=-5.0, dst='A'),
#  Row(faa='OKC', name='Will Rogers World', lat=35.393089294433594, lon=-97.6007308959961, alt=1295, tz=-6.0, dst='A'),
#  Row(faa='OLF', name='LM Clayton Airport', lat=48.094444274902344, lon=-105.57499694824219, alt=1986, tz=-7.0, dst='A'),
#  Row(faa='OLH', name='Old Harbor Airport', lat=57.218055725097656, lon=-153.2697296142578, alt=55, tz=-9.0, dst='A'),
#  Row(faa='OLM', name='Olympia Regional Airpor', lat=46.96940612792969, lon=-122.90254211425781, alt=209, tz=-7.0, dst='A'),
#  Row(faa='OLS', name='Nogales Intl', lat=31.417722702026367, lon=-110.84789276123047, alt=3955, tz=-7.0, dst='A'),
#  Row(faa='OLV', name='Olive Branch Muni', lat=34.87694549560547, lon=-89.78333282470703, alt=350, tz=-6.0, dst='A'),
#  Row(faa='OMA', name='Eppley Afld', lat=41.303165435791016, lon=-95.8940658569336, alt=984, tz=-6.0, dst='A'),
#  Row(faa='OME', name='Nome', lat=64.51219940185547, lon=-165.44525146484375, alt=37, tz=-9.0, dst='A'),
#  Row(faa='OMN', name='Ormond Beach municipal Airport', lat=29.180400848388672, lon=-81.06497192382812, alt=28, tz=-5.0, dst='A'),
#  Row(faa='ONH', name='Oneonta Municipal Airport', lat=42.524723052978516, lon=-75.06444549560547, alt=1763, tz=-5.0, dst='A'),
#  Row(faa='ONP', name='Newport Municipal Airport', lat=44.580360412597656, lon=-124.05791473388672, alt=160, tz=8.0, dst='A'),
#  Row(faa='ONT', name='Ontario Intl', lat=34.055999755859375, lon=-117.6011962890625, alt=944, tz=-8.0, dst='A'),
#  Row(faa='OOK', name='Toksook Bay Airport', lat=60.54138946533203, lon=-165.08721923828125, alt=59, tz=-10.0, dst='A'),
#  Row(faa='OPF', name='Opa Locka', lat=25.906999588012695, lon=-80.27838897705078, alt=8, tz=-5.0, dst='A'),
#  Row(faa='OQU', name='Quonset State Airport', lat=41.597137451171875, lon=-71.41213989257812, alt=18, tz=-4.0, dst='A'),
#  Row(faa='ORD', name='Chicago Ohare Intl', lat=41.97860336303711, lon=-87.90483856201172, alt=668, tz=-6.0, dst='A'),
#  Row(faa='ORF', name='Norfolk Intl', lat=36.89461135864258, lon=-76.20122528076172, alt=26, tz=-5.0, dst='A'),
#  Row(faa='ORH', name='Worcester Regional Airport', lat=42.26729965209961, lon=-71.87570190429688, alt=1009, tz=-5.0, dst='A'),
#  Row(faa='ORI', name='Port Lions Airport', lat=57.885276794433594, lon=-152.8461151123047, alt=52, tz=-9.0, dst='A'),
#  Row(faa='ORL', name='Executive', lat=28.54546356201172, lon=-81.33293914794922, alt=113, tz=-5.0, dst='A'),
#  Row(faa='ORT', name='Northway', lat=62.961334228515625, lon=-141.92913818359375, alt=1716, tz=-9.0, dst='A'),
#  Row(faa='ORV', name='Robert Curtis Memorial Airport', lat=66.81749725341797, lon=-161.022216796875, alt=55, tz=-9.0, dst='A'),
#  Row(faa='OSC', name='Oscoda Wurtsmith', lat=44.45155715942383, lon=-83.39405059814453, alt=634, tz=-5.0, dst='A'),
#  Row(faa='OSH', name='Wittman Regional Airport', lat=44.02498245239258, lon=-88.55133819580078, alt=790, tz=-5.0, dst='A'),
#  Row(faa='OSU', name='Ohio State University Airport', lat=40.07979965209961, lon=-83.072998046875, alt=905, tz=-5.0, dst='U'),
#  Row(faa='OTH', name='Southwest Oregon Regional Airport', lat=43.41709899902344, lon=-124.24600219726562, alt=17, tz=-8.0, dst='A'),
#  Row(faa='OTS', name='Anacortes Airport', lat=48.4988899230957, lon=-122.6624984741211, alt=241, tz=-8.0, dst='A'),
#  Row(faa='OTZ', name='Ralph Wien Mem', lat=66.88468170166016, lon=-162.5985565185547, alt=11, tz=-9.0, dst='A'),
#  Row(faa='OWB', name='Owensboro Daviess County Airport', lat=37.7401008605957, lon=-87.16680145263672, alt=406, tz=-6.0, dst='A'),
#  Row(faa='OWD', name='Norwood Memorial Airport', lat=42.190528869628906, lon=-71.17294311523438, alt=49, tz=-5.0, dst='A'),
#  Row(faa='OXC', name='Waterbury-Oxford Airport', lat=41.478553771972656, lon=-73.13524627685547, alt=726, tz=-4.0, dst='A'),
#  Row(faa='OXD', name='Miami University Airport', lat=39.502262115478516, lon=-84.78437805175781, alt=1040, tz=-5.0, dst='U'),
#  Row(faa='OXR', name='Oxnard - Ventura County', lat=34.20083236694336, lon=-119.20722198486328, alt=15, tz=-8.0, dst='A'),
#  Row(faa='OZA', name='Ozona Muni', lat=30.735280990600586, lon=-101.20297241210938, alt=2381, tz=-6.0, dst='A'),
#  Row(faa='P08', name='Coolidge Municipal Airport', lat=32.9359016418457, lon=-111.427001953125, alt=1574, tz=-7.0, dst='A'),
#  Row(faa='P52', name='Cottonwood Airport', lat=34.72999954223633, lon=-112.03500366210938, alt=3550, tz=-7.0, dst='A'),
#  Row(faa='PAE', name='Snohomish Co', lat=47.906341552734375, lon=-122.28156280517578, alt=606, tz=-8.0, dst='A'),
#  Row(faa='PAH', name='Barkley Regional Airport', lat=37.06028747558594, lon=-88.77295684814453, alt=410, tz=-6.0, dst='A'),
#  ...]

# %% [markdown]
# e nosso dataframe já está pronto para trabalharmos com ele!
# Vamos seguir com as tarefas:

# %%
from pyspark.sql.functions import col, when, length
import re
#with sql
qa_faa_df = spark.sql("""
    select
        *,
        case
            when 
               faa is null or faa like '' then 'M'
            when 
               faa rlike '^[a-zA-Z ]*$' 
               or faa rlike '^([^0-9]*)$'
               and length(faa) between 3 and 5 then 'F'
            else
               faa
        end as qa_faa
    from airports_view
    """)

qa_faa_df.show()

#and with the rdd
faa_airport_rdd = airport_df.select('faa').rdd.map(lambda el: "M" if el[0] == None or el[0] == "" else ("F" if ((len(el[0]) < 3 and len(el[0]) > 5) or not re.match('^[^0-9a-zA-Z]+$',el[0])) else el[0] ))
faa_airport_rdd.collect()

airport_df = airport_df.withColumn("qa_faa", 
                    when((col("faa") == "") |
                    (col("faa").isNull())   |
                    (col('faa').rlike('\t') |
                    (col('faa').rlike(' +')))     , "M")\
                    .when(
                        (length("faa") < 3) & 
                        (length("faa") > 5) &
                        (col('faa').rlike('^[a-zA-Z ]*$')) | (col('faa').rlike('^([^0-9]*)$')), "F"
                    )\
                    .otherwise(col('faa'))
                )
airport_df.select('qa_faa').show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+------+
# |faa|                name|      lat|        lon| alt|  tz|dst|qa_faa|
# +---+--------------------+---------+-----------+----+----+---+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|   04G|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|   06A|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A|   06C|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|   06N|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|   09J|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|   0A9|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|   0G6|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|   0G7|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|   0P2|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|   0S9|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|   0W3|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|   10C|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|   17G|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|   19A|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|   1A3|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A|   1B9|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|   1C9|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|   1CS|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|   1G3|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|   1OH|
# +---+--------------------+---------+-----------+----+----+---+------+
# only showing top 20 rows
#
# +------+
# |qa_faa|
# +------+
# |   04G|
# |   06A|
# |   06C|
# |   06N|
# |   09J|
# |   0A9|
# |   0G6|
# |   0G7|
# |   0P2|
# |   0S9|
# |   0W3|
# |   10C|
# |   17G|
# |   19A|
# |   1A3|
# |   1B9|
# |   1C9|
# |   1CS|
# |   1G3|
# |   1OH|
# +------+
# only showing top 20 rows

# %% [markdown]
# oi

# %%
#with sql
qa_name_df = spark.sql("""
    select
        *,
        case
            when 
               name is null or faa like '' then 'M'
            else
               name
        end as qa_name
    from airports_view
    """)
qa_name_df.show()

#and with rdd
def qa_name_mapping(el):
    if not el or el == "":
        return "M"
    else:
        return el
result = airport_rdd.map(lambda el: qa_name_mapping(el['name'])).collect()
print(result)

airport_df = airport_df.withColumn("qa_name", 
                    when((col("name") == "")     |
                        (col("name").isNull())  |
                        (col('faa').rlike('\t') |
                        (col('faa').rlike(' +'))), "M")\
                    .otherwise(col('name'))
                )
airport_df.select('qa_name').show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+--------------------+
# |faa|                name|      lat|        lon| alt|  tz|dst|             qa_name|
# +---+--------------------+---------+-----------+----+----+---+--------------------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|   Lansdowne Airport|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|Moton Field Munic...|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A| Schaumburg Regional|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|     Randall Airport|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|Jekyll Island Air...|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|Elizabethton Muni...|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|Williams County A...|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|Finger Lakes Regi...|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|Shoestring Aviati...|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|Jefferson County ...|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|Harford County Ai...|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|  Galt Field Airport|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|Port Bucyrus-Craw...|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|Jackson County Ai...|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|Martin Campbell F...|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A| Mansfield Municipal|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|Frazier Lake Airpark|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|Clow Internationa...|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|  Kent State Airport|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|     Fortman Airport|
# +---+--------------------+---------+-----------+----+----+---+--------------------+
# only showing top 20 rows
#
# ['Lansdowne Airport', 'Moton Field Municipal Airport', 'Schaumburg Regional', 'Randall Airport', 'Jekyll Island Airport', 'Elizabethton Municipal Airport', 'Williams County Airport', 'Finger Lakes Regional Airport', 'Shoestring Aviation Airfield', 'Jefferson County Intl', 'Harford County Airport', 'Galt Field Airport', 'Port Bucyrus-Crawford County Airport', 'Jackson County Airport', 'Martin Campbell Field Airport', 'Mansfield Municipal', 'Frazier Lake Airpark', 'Clow International Airport', 'Kent State Airport', 'Fortman Airport', 'Point Roberts Airpark', 'Lowell City Airport', 'Suwannee County Airport', 'Forest Lake Airport', 'Grove City Airport', 'Mark Anton Airport', 'Jefferson County Airpark', 'Somerset County Airport', 'Quincy Municipal Airport', 'Atmautluak Airport', 'Heber City Municipal Airport', 'Lynden Airport', 'Ephraim-Gibraltar Airport', 'Wadsworth Municipal', 'Ashland County Airport', 'Ridgeland Airport', 'Put-in-Bay Airport', 'Perry-Foley Airport', 'Braceville Airport', 'Cherokee County Airport', 'Gilmer County Airport', 'Chemehuevi Valley', 'Polk County Airport - Cornelius Moore Field', 'Clayton County Tara Field', 'Isbell Field Airport', 'Robertson Field', 'Pittsburgh-Monroeville Airport', 'Hamburg Inc Airport', 'Youngstown Elser Metro Airport', 'Putnam County Airport', 'Dell Flight Strip', 'Madison GA Municipal Airport', 'DeFuniak Springs Airport', 'Fernandina Beach Municipal Airport', 'East Troy Municipal Airport', 'Ocean Isle Beach Airport', 'Griffin-Spalding County Airport', 'Tok Junction Airport', 'Big Timber Airport', 'Florence', 'Welke Airport', 'Cairo-Grady County Airport', 'Spring Hill Airport', 'Foster Field', 'Germack Airport', 'Spitfire Aerodrome', 'Garland Airport', 'Richland Airport', 'Bamberg County Airport', 'Covington Municipal Airport', 'Barwick Lafayette Airport', 'Phoenix Regional Airport', 'Apalachicola Regional Airport', 'Lehigh Valley Intl', 'Abilene Rgnl', 'Ambler Airport', 'Albuquerque International Sunport', 'Aberdeen Regional Airport', 'Southwest Georgia Regional Airport', 'Nantucket Mem', 'Waco Rgnl', 'Arcata', 'Atlantic City Intl', 'Adak Airport', 'Ardmore Muni', 'Kodiak', 'Addison', 'Andrews Afb', 'Allakaket Airport', 'Alexandria Intl', 'Kake Airport', 'Fort Worth Alliance Airport', 'Allegheny County Airport', 'Angoon Seaplane Base', 'Augusta Rgnl At Bush Fld', 'Athens Ben Epps Airport', 'Alliance Municipal Airport', 'Municipal Airport', 'Wainwright Airport', 'Lee C Fine Memorial Airport', 'Atka Airport', 'Akron Fulton Intl', 'Akiak Airport', 'Akhiok Airport', 'King Salmon', 'Anaktuvuk Pass Airport', 'Albany Intl', 'Alice Intl', 'Alamogordo White Sands Regional Airport', 'Waterloo Regional Airport', 'San Luis Valley Regional Airport', 'Walla Walla Regional Airport', 'Alexandria', 'Alitak Seaplane Base', 'Rick Husband Amarillo Intl', 'Anniston Metro', 'Ted Stevens Anchorage Intl', 'Anderson Rgnl', 'Aniak Airport', 'Annette Island', 'Lee Airport', 'Tri-State Steuben County Airport', 'Anvik Airport', 'Lima Allen County Airport', 'Altoona Blair Co', 'Amook Bay Seaplane Base', 'Centennial', 'Napa County Airport', 'Naples Muni', 'Phillips Aaf', 'Alpena County Regional Airport', 'Klawock Seaplane Base', 'Acadiana Rgnl', 'Ann Arbor Municipal Airport', 'Arctic Village Airport', 'Watertown Intl', 'Lakeland', 'Aspen Pitkin County Sardy Field', 'Boire Field Airport', 'Astoria Regional Airport', 'Atqasuk Edward Burnell Sr Memorial Airport', 'Hartsfield Jackson Atlanta Intl', 'Camp Mabry Austin City', 'Appleton', 'Watertown Regional Airport', 'Augusta State', 'Alakanuk Airport', 'Austin Bergstrom Intl', 'Wausau Downtown Airport', 'Asheville Regional Airport', 'Executive', 'Wilkes Barre Scranton Intl', 'Marana Regional', 'Avalon', 'Phoenix-Mesa Gateway', 'Kalamazoo', 'Beale Afb', 'Barksdale Afb', 'Barnes Municipal', 'Wings Field', 'Bryce Canyon', 'Boca Raton', 'Baudette Intl', 'Bradley Intl', 'Igor I Sikorsky Mem', 'Beech Factory Airport', 'Laurence G Hanscom Fld', 'Southwest Michigan Regional  ...
# +--------------------+
# |             qa_name|
# +--------------------+
# |   Lansdowne Airport|
# |Moton Field Munic...|
# | Schaumburg Regional|
# |     Randall Airport|
# |Jekyll Island Air...|
# |Elizabethton Muni...|
# |Williams County A...|
# |Finger Lakes Regi...|
# |Shoestring Aviati...|
# |Jefferson County ...|
# |Harford County Ai...|
# |  Galt Field Airport|
# |Port Bucyrus-Craw...|
# |Jackson County Ai...|
# |Martin Campbell F...|
# | Mansfield Municipal|
# |Frazier Lake Airpark|
# |Clow Internationa...|
# |  Kent State Airport|
# |     Fortman Airport|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# Curiosidade

# %%
#with sql
qa_lat_df = spark.sql("""
    select
        *,
        case
            when 
               lat is null or faa like '' then 'M'
            when
               lat > 180.0 or lat < -180.0 then 'I'
            when
                lat rlike '/^\w*?[a-zA-Z]\w*$/' then 'A'
            else
               lat
        end as qa_lat
    from airports_view
    """)
qa_name_df.show()

#and with rdd
def qa_lat_mapping(el):
    if not el['lat'] or el['lat'] == "":
        return "M"
    elif el['lat'] > 180.0 and el['lat'] < -180.0:
        return 'I'
    elif not re.match('^([1-9]\d*(\.|\,)\d*|0?(\.|\,)\d*[1-9]\d*|[1-9]\d*)$',str(el['lat'])):
        return 'A'
    else:
        return el['lat']

result = airport_rdd.map(qa_lat_mapping).collect()
print(result)

airport_df = airport_df.withColumn("qa_lat", 
                    when((col("lat") == "")      |
                        (col("lat").isNull())   |
                        (col('lat').rlike('\t') |
                        (col('lat').rlike(' +'))), "M")\
                    .when(
                        (col("lat") > '180.0') & 
                        (col("lat") < '-180.0'), "I"
                    )\
                    .when((col('lat').rlike('[a-zA-Z ]')), "A")
                    .otherwise(col('lat'))
                )
airport_df.select('qa_lat').show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+--------------------+
# |faa|                name|      lat|        lon| alt|  tz|dst|             qa_name|
# +---+--------------------+---------+-----------+----+----+---+--------------------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|   Lansdowne Airport|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|Moton Field Munic...|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A| Schaumburg Regional|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|     Randall Airport|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|Jekyll Island Air...|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|Elizabethton Muni...|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|Williams County A...|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|Finger Lakes Regi...|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|Shoestring Aviati...|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|Jefferson County ...|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|Harford County Ai...|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|  Galt Field Airport|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|Port Bucyrus-Craw...|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|Jackson County Ai...|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|Martin Campbell F...|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A| Mansfield Municipal|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|Frazier Lake Airpark|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|Clow Internationa...|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|  Kent State Airport|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|     Fortman Airport|
# +---+--------------------+---------+-----------+----+----+---+--------------------+
# only showing top 20 rows
#
# [41.13047409057617, 32.4605712890625, 41.989341735839844, 41.43191146850586, 31.074472427368164, 36.37122344970703, 41.46730422973633, 42.88356399536133, 39.794822692871094, 48.053810119628906, 39.566837310791016, 42.402889251708984, 40.78155517578125, 34.175865173339844, 35.015804290771484, 42.0001335144043, 54.01333236694336, 41.69597625732422, 41.151390075683594, 40.55532455444336, 48.97972106933594, 42.95391845703125, 30.300125122070312, 45.247745513916016, 41.146026611328125, 35.48625183105469, 40.3602180480957, 40.03887176513672, 30.597869873046875, 60.866668701171875, 40.48180389404297, 48.955894470214844, 45.13541793823242, 41.00315856933594, 40.90297317504883, 32.49341583251953, 41.35210037231445, 30.069278717041016, 41.21116638183594, 34.312217712402344, 34.62822341918945, 34.52888870239258, 34.01869583129883, 33.38909912109375, 34.47369384765625, 41.689334869384766, 40.452640533447266, 42.70089340209961, 40.961795806884766, 39.6335563659668, 44.735748291015625, 33.612125396728516, 30.731111526489258, 30.611833572387695, 42.79716491699219, 33.908504486083984, 33.22697067260742, 63.329444885253906, 45.80638885498047, 43.982818603515625, 45.72111129760742, 30.887977600097656, 41.34735870361328, 42.46644592285156, 41.77783203125, 39.735565185546875, 44.80652618408203, 43.283355712890625, 33.304527282714844, 33.63230895996094, 34.688480377197266, 32.99169921875, 29.72760581970215, 40.65208435058594, 32.411319732666016, 67.10639190673828, 35.04022216796875, 45.449100494384766, 31.535499572753906, 41.2530517578125, 31.61128807067871, 40.978111267089844, 39.457584381103516, 51.87799835205078, 34.30083465576172, 57.74996566772461, 32.96855926513672, 38.81080627441406, 66.5519027709961, 31.32740020751953, 56.961387634277344, 32.98777770996094, 40.354400634765625, 57.50361251831055, 33.36994552612305, 33.94860076904297, 42.0533332824707, 33.64938735961914, 70.63805389404297, 38.09603500366211, 52.220279693603516, 41.037498474121094, 60.90277862548828, 56.9386100769043, 58.67677688598633, 68.13359832763672, 42.748268127441406, 27.740888595581055, 32.839900970458984, 42.557098388671875, 37.435001373291016, 46.09489822387695, 38.80634689331055, 56.899444580078125, 35.21936798095703, 33.588165283203125, 61.17436218261719, 34.49458312988281, 61.581600189208984, 55.04243469238281, 38.942779541015625, 41.63969802856445, 62.64670181274414, 40.70747756958008, 40.29637145996094, 57.47138977050781, 39.57012939453125, 38.21319580078125, 26.152618408203125, 39.46622085571289, 45.07809829711914, 55.554656982421875, 30.037757873535156, 42.13227462768555, 68.11470031738281, 43.991920471191406, 45.92777633666992, 39.223201751708984, 42.7817497253418, 46.1579704284668, 70.46730041503906, 33.63671875, 30.316659927368164, 44.25752639770508, 44.91400146484375, 44.320648193359375, 62.68000030517578, 30.194528579711914, 44.92628479003906, 35.436195373535156, 27.591388702392578, 41.338478088378906, 32.4095573425293, 33.404998779296875, 33.30783462524414, 42.2348747253418, 39.13608932495117, 32.5018196105957, 42.1579475402832, 40.13750076293945, 37.706443786621094, 26.37849998474121, 48.72844314575195, 41.93888854980469, 41.16347122192383, 37.69391632080078, 42.46995162963867, 42.12858200073242, 60.77977752685547, 41.8031005859375, 41.874000549316406, 47.529998779296875, 35.433597564697266, 30.62678337097168, 40.7724723815918, 32.47740936279297, 32.410831451416016, 30.97159767150879, 42.20869064331055, 44.80744552612305, 44.44976806640625, 33.56294250488281, 41.16805648803711, 31.84952735900879, 63.99454879760742, 45.80921173095703, 46.775840759277344, 42.74277877807617, 30.410425186157227, 39.90888977050781, 47.51072311401367, 65.9816665649414, 32.71904754638672, 39.70166778564453, 36.5319938659668, 22.0228328704834, 41.51750183105469, 37.78730010986328, 44.3047981262207, 35.565101623535156, 37.295799255371094, 33.61916732788086, 48.792694091796875, 38.5451774597168, 41.551998138427734, 39.146018981933594, 40.47711181640625, 59.36124801635742, 36.124 ...
# +---------+
# |   qa_lat|
# +---------+
# |41.130474|
# | 32.46057|
# | 41.98934|
# | 41.43191|
# |31.074472|
# |36.371223|
# |41.467304|
# |42.883564|
# |39.794823|
# | 48.05381|
# |39.566837|
# | 42.40289|
# |40.781555|
# |34.175865|
# |35.015804|
# |42.000134|
# |54.013332|
# |41.695976|
# | 41.15139|
# |40.555325|
# +---------+
# only showing top 20 rows

# %% [markdown]
# em

# %%
#with sql
qa_lon_df = spark.sql("""
    select
        *,
        case
            when 
               lon is null or lon like '' then 'M'
            when
               lon > 180.0 or lon < -180.0 then 'I'
            when
                lon rlike '/^\w*?[a-zA-Z]\w*$/' then 'A'
            else
               lon
        end as qa_lon
    from airports_view
    """)
qa_lon_df.show()

airport_df = airport_df.withColumn("qa_lon", 
                    when((col("lon") == "")      |
                        (col("lon").isNull())   |
                        (col('lon').rlike('\t') |
                        (col('lon').rlike(' +'))), "M")\
                    .when(
                        (col("lon") > '180.0') & 
                        (col("lon") < '-180.0'), "I"
                    )\
                    .when((col('lon').rlike('[a-zA-Z ]')), "A")
                    .otherwise(col('lon'))
                )
airport_df.select('qa_lon').show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+-----------+
# |faa|                name|      lat|        lon| alt|  tz|dst|     qa_lon|
# +---+--------------------+---------+-----------+----+----+---+-----------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|  -80.61958|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|  -85.68003|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A|  -88.10124|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|  -74.39156|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|  -81.42778|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A| -82.173416|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A| -84.506775|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A| -76.781235|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U| -76.647194|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|-122.810646|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|   -76.2024|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U| -88.375114|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|  -82.97481|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|   -83.5616|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|  -84.34683|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A|  -71.19677|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A| -124.76833|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U| -88.129234|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|  -81.41511|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|  -84.38662|
# +---+--------------------+---------+-----------+----+----+---+-----------+
# only showing top 20 rows
#
# +-----------+
# |     qa_lon|
# +-----------+
# |  -80.61958|
# |  -85.68003|
# |  -88.10124|
# |  -74.39156|
# |  -81.42778|
# | -82.173416|
# | -84.506775|
# | -76.781235|
# | -76.647194|
# |-122.810646|
# |   -76.2024|
# | -88.375114|
# |  -82.97481|
# |   -83.5616|
# |  -84.34683|
# |  -71.19677|
# | -124.76833|
# | -88.129234|
# |  -81.41511|
# |  -84.38662|
# +-----------+
# only showing top 20 rows

# %% [markdown]
# pessoa

# %%
#with sql
qa_alt_df = spark.sql("""
    select
        *,
        case
            when 
               alt is null or alt like '' then 'M'
            when
               alt < 0 then 'I'
            when
               alt rlike '/^\w*?[a-zA-Z]\w*$/' then 'A'
            else
               alt
        end as qa_alt
    from airports_view
    """)
qa_alt_df.show()

airport_df = airport_df.withColumn("qa_alt", 
                     when((col("alt") == "")      |
                           (col("alt").isNull())   |
                           (col('alt').rlike('\t') |
                           (col('alt').rlike(' +'))), "M")\
                     .when((col("alt") < '0'), "I")\
                     .when( (col('alt').rlike('[a-zA-Z ]')), "A")
                     .otherwise(col('alt'))
               )
airport_df.show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+------+
# |faa|                name|      lat|        lon| alt|  tz|dst|qa_alt|
# +---+--------------------+---------+-----------+----+----+---+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|  1044|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|   264|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A|   801|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|   523|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|    11|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|  1593|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|   730|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|   492|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|  1000|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|   108|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|   409|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|   875|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|  1003|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|   951|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|  1789|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A|   122|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|   152|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|   670|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|  1134|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|   885|
# +---+--------------------+---------+-----------+----+----+---+------+
# only showing top 20 rows
#
# +---+--------------------+---------+-----------+----+----+---+------+--------------------+---------+-----------+------+
# |faa|                name|      lat|        lon| alt|  tz|dst|qa_faa|             qa_name|   qa_lat|     qa_lon|qa_alt|
# +---+--------------------+---------+-----------+----+----+---+------+--------------------+---------+-----------+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|   04G|   Lansdowne Airport|41.130474|  -80.61958|  1044|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|   06A|Moton Field Munic...| 32.46057|  -85.68003|   264|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A|   06C| Schaumburg Regional| 41.98934|  -88.10124|   801|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|   06N|     Randall Airport| 41.43191|  -74.39156|   523|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|   09J|Jekyll Island Air...|31.074472|  -81.42778|    11|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|   0A9|Elizabethton Muni...|36.371223| -82.173416|  1593|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|   0G6|Williams County A...|41.467304| -84.506775|   730|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|   0G7|Finger Lakes Regi...|42.883564| -76.781235|   492|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|   0P2|Shoestring Aviati...|39.794823| -76.647194|  1000|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|   0S9|Jefferson County ...| 48.05381|-122.810646|   108|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|   0W3|Harford County Ai...|39.566837|   -76.2024|   409|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|   10C|  Galt Field Airport| 42.40289| -88.375114|   875|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|   17G|Port Bucyrus-Craw...|40.781555|  -82.97481|  1003|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|   19A|Jackson County Ai...|34.175865|   -83.5616|   951|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|   1A3|Martin Campbell F...|35.015804|  -84.34683|  1789|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A|   1B9| Mansfield Municipal|42.000134|  -71.19677|   122|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|   1C9|Frazier Lake Airpark|54.013332| -124.76833|   152|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|   1CS|Clow Internationa...|41.695976| -88.129234|   670|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|   1G3|  Kent State Airport| 41.15139|  -81.41511|  1134|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|   1OH|     Fortman Airport|40.555325|  -84.38662|   885|
# +---+--------------------+---------+-----------+----+----+---+------+--------------------+---------+-----------+------+
# only showing top 20 rows

# %% [markdown]
# como

# %%
airport_df.select('qa_dst').show()

# %%
#with sql
qa_tz_df = spark.sql("""
    select
        *,
        case
            when 
               tz is null or alt like '' then 'M'
            when
               tz <= -11 or tz >= 14 then 'I'
            when
               tz rlike '/^\w*?[a-zA-Z]\w*$/' then 'A'
            else
               tz
        end as qa_tz
    from airports_view
    """)
qa_tz_df.show()

airport_df =airport_df.withColumn("qa_tz", 
                  when((col("tz") == "")      |
                        (col("tz").isNull())   |
                        (col('tz').rlike('\t') |
                        (col('tz').rlike(' +')) ), "M")\
                  .when((col("tz") <= '-11.0') &
                        (col("tz") >= '14.0'), "I")\
                  .when( (col('tz').rlike('[a-zA-Z ]')), "A")
                  .otherwise(col('tz'))
            )
airport_df.select('qa_tz').show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+-----+
# |faa|                name|      lat|        lon| alt|  tz|dst|qa_tz|
# +---+--------------------+---------+-----------+----+----+---+-----+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A| -5.0|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A| -5.0|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A| -6.0|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A| -5.0|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A| -4.0|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A| -4.0|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A| -5.0|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A| -5.0|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U| -5.0|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A| -8.0|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A| -5.0|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U| -6.0|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A| -5.0|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U| -4.0|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A| -4.0|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A| -5.0|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A| -8.0|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U| -6.0|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A| -4.0|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U| -5.0|
# +---+--------------------+---------+-----------+----+----+---+-----+
# only showing top 20 rows
#
# +-----+
# |qa_tz|
# +-----+
# | -5.0|
# | -5.0|
# | -6.0|
# | -5.0|
# | -4.0|
# | -4.0|
# | -5.0|
# | -5.0|
# | -5.0|
# | -8.0|
# | -5.0|
# | -6.0|
# | -5.0|
# | -4.0|
# | -4.0|
# | -5.0|
# | -8.0|
# | -6.0|
# | -4.0|
# | -5.0|
# +-----+
# only showing top 20 rows

# %% [markdown]
# está?

# %%
expected_categorys = ["E", "A", "S", "O", "Z", "N", "U"]

#with sql
qa_dst_df = spark.sql("""
    select
        *,
        case
            when 
                dst is null or dst like '' then 'M'
            when
                dst not in ('E', 'A', 'S', 'O', 'Z', 'N', 'U') then 'C'
            when
                dst rlike '^[0-9]*$' then 'N'
        end as qa_dst
    from airports_view
    """)

qa_dst_df.show()

airport_df =airport_df.withColumn("qa_dst", 
                when((col("dst") == "")      |
                    (col("dst").isNull())   |
                    (col('dst').rlike('\t') |
                    (col('dst').rlike(' +')) ), "M")\
                .when( (col('dst').rlike('^[0-9]*$') == True), "N")\
                .when((col("dst").isin(expected_categorys) == False) , "C")\
                .otherwise(col('dst'))
            )
# Out:
# +---+--------------------+---------+-----------+----+----+---+------+
# |faa|                name|      lat|        lon| alt|  tz|dst|qa_dst|
# +---+--------------------+---------+-----------+----+----+---+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|  null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|  null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|  null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|  null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|  null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|  null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A|  null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|  null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|  null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|  null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|  null|
# +---+--------------------+---------+-----------+----+----+---+------+
# only showing top 20 rows
#
# +------+
# |qa_dst|
# +------+
# |     A|
# |     A|
# |     A|
# |     A|
# |     A|
# |     A|
# |     A|
# |     A|
# |     U|
# |     A|
# |     A|
# |     U|
# |     A|
# |     U|
# |     A|
# |     A|
# |     A|
# |     U|
# |     A|
# |     U|
# +------+
# only showing top 20 rows

# %%
#Após feitas as transformações, vamos salvar nosso arquivo
airport_df.write.parquet("qa_outputs/airport_qa.parquet")
airport_df.show()
# Out:
# +---+--------------------+---------+-----------+----+----+---+------+--------------------+---------+-----------+------+-----+------+
# |faa|                name|      lat|        lon| alt|  tz|dst|qa_faa|             qa_name|   qa_lat|     qa_lon|qa_alt|qa_tz|qa_dst|
# +---+--------------------+---------+-----------+----+----+---+------+--------------------+---------+-----------+------+-----+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044|-5.0|  A|   04G|   Lansdowne Airport|41.130474|  -80.61958|  1044| -5.0|     A|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264|-5.0|  A|   06A|Moton Field Munic...| 32.46057|  -85.68003|   264| -5.0|     A|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801|-6.0|  A|   06C| Schaumburg Regional| 41.98934|  -88.10124|   801| -6.0|     A|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523|-5.0|  A|   06N|     Randall Airport| 41.43191|  -74.39156|   523| -5.0|     A|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11|-4.0|  A|   09J|Jekyll Island Air...|31.074472|  -81.42778|    11| -4.0|     A|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593|-4.0|  A|   0A9|Elizabethton Muni...|36.371223| -82.173416|  1593| -4.0|     A|
# |0G6|Williams County A...|41.467304| -84.506775| 730|-5.0|  A|   0G6|Williams County A...|41.467304| -84.506775|   730| -5.0|     A|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492|-5.0|  A|   0G7|Finger Lakes Regi...|42.883564| -76.781235|   492| -5.0|     A|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000|-5.0|  U|   0P2|Shoestring Aviati...|39.794823| -76.647194|  1000| -5.0|     U|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108|-8.0|  A|   0S9|Jefferson County ...| 48.05381|-122.810646|   108| -8.0|     A|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409|-5.0|  A|   0W3|Harford County Ai...|39.566837|   -76.2024|   409| -5.0|     A|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875|-6.0|  U|   10C|  Galt Field Airport| 42.40289| -88.375114|   875| -6.0|     U|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003|-5.0|  A|   17G|Port Bucyrus-Craw...|40.781555|  -82.97481|  1003| -5.0|     A|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951|-4.0|  U|   19A|Jackson County Ai...|34.175865|   -83.5616|   951| -4.0|     U|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789|-4.0|  A|   1A3|Martin Campbell F...|35.015804|  -84.34683|  1789| -4.0|     A|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122|-5.0|  A|   1B9| Mansfield Municipal|42.000134|  -71.19677|   122| -5.0|     A|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152|-8.0|  A|   1C9|Frazier Lake Airpark|54.013332| -124.76833|   152| -8.0|     A|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670|-6.0|  U|   1CS|Clow Internationa...|41.695976| -88.129234|   670| -6.0|     U|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134|-4.0|  A|   1G3|  Kent State Airport| 41.15139|  -81.41511|  1134| -4.0|     A|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885|-5.0|  U|   1OH|     Fortman Airport|40.555325|  -84.38662|   885| -5.0|     U|
# +---+--------------------+---------+-----------+----+----+---+------+--------------------+---------+-----------+------+-----+------+
# only showing top 20 rows

# %% [markdown]
# # Planes Dataset
#
# ![Airport](attachment:./images/planes_snapshot.png "an airport Hangar")
# <p style="text-align: center;"> <a href="./glossary/planes_glossary.txt"> Planes Glossary </a> </p>
#
# Precisamos configurar esse novo dataset pra trabalharmos:

# %%
#lets describe our new file
planes_file = "./datasets/planes.csv"

#set our schema (that you can see on glossary)
schema = StructType([
    StructField("tailnum",      StringType()),
    StructField("year",         IntegerType()),
    StructField("type",         StringType()),
    StructField("manufacturer", StringType()),
    StructField("model",   StringType()),
    StructField("engines", IntegerType()),
    StructField("seats",   IntegerType()),
    StructField("speed",   IntegerType()),
    StructField("engine",  StringType())
])

#and create a new dataframe 
planes_df = spark \
           .read.format("csv") \
           .option("inferSchema", "false") \
           .option("header", "True")\
           .schema(schema)\
           .csv(planes_file)

#lets take the rdd to work with too
planes_rdd = planes_df.rdd

#don't forget to create a view (important to work with spark sql)
planes_df.createOrReplaceTempView('planes_view')

# %% [markdown]
# Com nosso dataset configurado, estamos prontos para completar as tarefas a serem realizadas, que estão descritas a seguir :)

# %% [markdown]
# Você

# %%
#with sql
qa_tailnum_df = spark.sql("""
    select
        *,
        case
            when 
               tailnum is null or tailnum like '' then 'M'
            when
                length(tailnum) != 5 then 'S'
            when
                 substring(tailnum, 1, 1) not like 'N'
                     and
                     substring(tailnum, -1, -1) not like 'Z'
                     and
                 substring(tailnum, 2, 4) rlike '^([^0-9]*)$'
                then 'F'
            when 
                 substring(tailnum, 1, 1) = 'I' 
                     or
                 substring(tailnum, 1, 1) = 'O'
                     or
                 substring(tailnum, 1, 1) = '0' 
                then 'FE'
            when
                substring(tailnum, 1, 1) != 'I'
                then 'FN'
            else
               tailnum
        end as qa_tailnum
    from planes_view
    """)
qa_tailnum_df.show()
#lets save it
#qa_tailnum_df.write.parquet("output/qa_tailnum.parquet")
#we can check it too
tailnum_data = spark.read.parquet("output/qa_tailnum.parquet")
tailnum_data.show()

planes_df = planes_df.withColumn("qa_tailnum", 
                when((col("tailnum") == "")      |
                    (col("tailnum").isNull())   |
                    (col('tailnum').rlike('\t') |
                    (col('tailnum').rlike(' +'))), "M")\
                .when((length("tailnum") != 5), "S")\
                .when(
                    (col('tailnum').substr(1, 1) != 'N')   &
                    (col('tailnum').substr(-1, -1) != 'Z') & 
                    (col('tailnum').substr(2,4).rlike('^([^0-9]*)$')), "F")\
                .when((col("tailnum").substr(1,1) == "I")  |
                    (col("tailnum").substr(1,1) == "O") |
                    (col("tailnum").substr(1,1) == "0"), "FE")\
                .when((col("tailnum").substr(1,1) != "N"),  "FN")\
                .otherwise(col('tailnum'))
            )

planes_df.select('qa_tailnum').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         S|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         S|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# only showing top 20 rows
#
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         S|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         S|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# only showing top 20 rows
#
# +----------+
# |qa_tailnum|
# +----------+
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# |         S|
# +----------+
# only showing top 20 rows

# %% [markdown]
# De

# %%
#with sql
qa_year_df = spark.sql("""
    select
        *,
        case
            when 
               year is null or year like '' then 'M'
            when
                year < 1950 then 'I'
            else
               year
        end as qa_year
    from planes_view
    """)
qa_year_df.show()

planes_df = planes_df.withColumn("qa_year", 
                when((col("year") == "")      |
                    (col("year").isNull())   |
                    (col('year').rlike('\t') |
                    (col('year').rlike(' +'))), "M")\
                .when((col("year") < 1950), "I")\
                .otherwise(col('year'))
            )
planes_df.select('qa_year').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+-------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_year|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+-------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1998|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|   2000|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   1999|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   2000|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   2000|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|   2000|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|   1998|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|   1998|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|   1995|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|   1987|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+-------+
# only showing top 20 rows
#
# +-------+
# |qa_year|
# +-------+
# |   1998|
# |   1999|
# |   1999|
# |   1999|
# |   1999|
# |   1999|
# |   1999|
# |   1999|
# |   1999|
# |   2000|
# |   1999|
# |   1999|
# |   1999|
# |   2000|
# |   2000|
# |   2000|
# |   1998|
# |   1998|
# |   1995|
# |   1987|
# +-------+
# only showing top 20 rows

# %% [markdown]
# Novo

# %%
type_categories = ['Fixed wing multi engine', 'fixed wing single engine', 'Rotorcraft']

#with sql
qa_type_df = spark.sql("""
    select
        *,
        case
            when 
               type is null or type like '' then 'M'
            when
               type not in ('Fixed wing multi engine', 'fixed wing single engine', 'Rotorcraft') 
               then 'C'
            else
               type
        end as qa_type
    from planes_view
    """)
qa_type_df.show()

planes_df = planes_df.withColumn("qa_type", 
                when((col("type") == "")      |
                    (col("type").isNull())   |
                    (col('type').rlike('\t') |
                    (col('type').rlike(' +'))), "M")\
                .when((col("type").isin(type_categories) == False),  "C")\
                .otherwise(col('type'))
            )

planes_df.select('qa_type').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------------------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|             qa_type|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------------------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|Fixed wing multi ...|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Fixed wing multi ...|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|Fixed wing multi ...|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|Fixed wing multi ...|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|Fixed wing multi ...|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|Fixed wing multi ...|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------------------+
# only showing top 20 rows
#
# +-------+
# |qa_type|
# +-------+
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# |      M|
# +-------+
# only showing top 20 rows

# %% [markdown]
# Que

# %%
manufacture_categories = ["AIRBUS", "BOEING","BOMBARDIER","CESSNA","EMBRAER","SIKORSKY","CANADAIR",
                          "PIPER","MCDONNELL DOUGLAS","CIRRUS","BELL","KILDALL GARY","LAMBERT RICHARD",
                          "BARKER JACK","ROBINSON HELICOPTER","GULFSTREAM","MARZ BARRY"]
#with sql
qa_manufacturer_df = spark.sql("""
    select
        *,
        case
            when 
               manufacturer is null or manufacturer like '' then 'M'
            when
               manufacturer not in ("%AIRBUS%", "BOEING","BOMBARDIER","CESSNA","EMBRAER","SIKORSKY","CANADAIR",
                                   "PIPER","MCDONNELL DOUGLAS","CIRRUS","BELL","KILDALL GARY","LAMBERT RICHARD%",
                                   "BARKER JACK","ROBINSON HELICOPTER","GULFSTREAM","MARZ BARRY") 
               then 'C'
            else
               manufacturer
        end as qa_manufacturer
    from planes_view
    """)
qa_manufacturer_df.show()

#using a udf
from pyspark.sql.functions import udf
from pyspark.sql.types import StructType


# dica do eugênio -> df.map(lambda x: any([x.contains(f"%{y}%") for y in MANUFACTURERS]))

@udf
def qa_manufacturer(el):
    if(any([el.__contains__(f"{y}") for y in manufacture_categories])):
        return el
    else:
        return "M"

planes_df.select("manufacturer", qa_manufacturer('manufacturer')).show()

#lets go back to our df

planes_df = planes_df.withColumn("qa_manufacturer", 
                when((col("manufacturer") == "")      |
                    (col("manufacturer").isNull()), "M")\
                .when(
                    (col("manufacturer").contains("AIRBUS%")) |
                    (col("manufacturer").contains("BOEING%")) |
                    (col("manufacturer").contains("BOMBARDIER%")) |
                    (col("manufacturer").contains("CESSNA%"))   |
                    (col("manufacturer").contains("EMBRAER%"))  |
                    (col("manufacturer").contains("SIKORSKY%")) |
                    (col("manufacturer").contains("CANADAIR%")) |
                    (col("manufacturer").contains("PIPER%"))    |
                    (col("manufacturer").contains("MCDONNELL DOUGLAS%")) |
                    (col("manufacturer").contains("CIRRUS%")) |
                    (col("manufacturer").contains("BELL%"))   |
                    (col("manufacturer").contains("KILDALL GARY%"))    |
                    (col("manufacturer").contains("LAMBERT RICHARD%")) |
                    (col("manufacturer").contains("BARKER JACK%"))     |
                    (col("manufacturer").contains("ROBINSON HELICOPTER%")) |
                    (col("manufacturer").contains("GULFSTREAM%")) |
                    (col("manufacturer").contains("MARZ BARRY%")), "C"
                    )\
                .otherwise(col('manufacturer'))
            )
planes_df.select('qa_manufacturer').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+---------------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_manufacturer|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+---------------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         BOEING|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|              C|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         BOEING|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         BOEING|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         BOEING|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         BOEING|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+---------------+
# only showing top 20 rows
#
# +----------------+-----------------------------+
# |    manufacturer|qa_manufacturer(manufacturer)|
# +----------------+-----------------------------+
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |          BOEING|                       BOEING|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|             AIRBUS INDUSTRIE|
# |          BOEING|                       BOEING|
# |          BOEING|                       BOEING|
# |          BOEING|                       BOEING|
# |          BOEING|                       BOEING|
# +----------------+-----------------------------+
# only showing top 20 rows
#
# +----------------+
# | qa_manufacturer|
# +----------------+
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |          BOEING|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |AIRBUS INDUSTRIE|
# |          BOEING|
# |          BOEING|
# |          BOEING|
# |          BOEING|
# +----------------+
# only showing top 20 rows

# %% [markdown]
# Boa

# %%
#with sql
qa_model_df = spark.sql("""
    select
        *,
        case
            when 
               model is null or model like '' then 'M'
            when
                 manufacturer = 'AIRBUS'
                     and
                 substring(model, 1, 1) != 'A'
                then 'F'
            when
                 manufacturer = 'BOEING'
                     and
                 substring(model, 1, 1) != '7'
                then 'F'
            when
                 (manufacturer = 'BOMBARDIER' or manufacturer = 'CANADAIR')
                     and
                 substring(model, 1, 1) != 'CL'
                then 'F'
            when
                 manufacturer = 'MCDONNELL DOUGLAS'
                     and
                (
                 substring(model, 1, 1) != 'MD' or
                 substring(model, 1, 1) != 'DC'
                 )
                then 'F'
            else
               model
        end as qa_model
    from planes_view
    """)
qa_model_df.show()

planes_df = planes_df.withColumn("qa_model", 
                when((col("model") == "")     |
                    (col("model").isNull())   |
                    (col('model').rlike('\t') |
                    (col('model').rlike(' +'))), "M")\
                .when(
                    (col('manufacturer') == "AIRBUS") &
                    (col('model').substr(1, 1) != 'A'), "F")\
                .when(
                    (col('manufacturer') == "BOEING") &
                    (col('model').substr(1, 1) != '7'), "F")\
                .when(
                    ((col('manufacturer') == "BOMBARDIER") |
                    (col('manufacturer') == "CANADAIR"))   &
                    (col('model').substr(1, 1) != 'CL'), "F")\
                .when(
                    (col('manufacturer') == "MCDONNELL DOUGLAS") &
                    ((col('model').substr(1, 1) != 'MD') |
                    (col('model').substr(1, 1) != 'DC')), "F")\
                .otherwise(col('model'))
            )
planes_df.select('qa_model').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_model|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan| 737-824|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|A320-214|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan| 767-332|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan| 767-332|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet| 757-224|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan| 767-332|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# only showing top 20 rows
#
# +--------+
# |qa_model|
# +--------+
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# | 737-824|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# |A320-214|
# | 767-332|
# | 767-332|
# | 757-224|
# | 767-332|
# +--------+
# only showing top 20 rows

# %% [markdown]
# Surpresa

# %%
#with sql
qa_engines_df = spark.sql("""
    select
        *,
        case
            when 
               engines is null or engines like '' then 'M'
            when
                engines < 1 or engines > 4 then 'S'
            when
                engines rlike '^([^0-9]*)$' = False
                then 'A'
            else
               engines
        end as qa_engines
    from planes_view
    """)
qa_engines_df.show()

planes_df = planes_df.withColumn("qa_engines", 
                when((col("engines") == "") |
                    (col("engines").isNull()), "M")\
                .when((col("engines") < 1) |
                    (col("engines") > 4), "I")\
                .when((col('engines').rlike('^[0-9]*$') == False), "A")\
                .otherwise(col('engines'))
            )
planes_df.select('qa_engines').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_engines|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         2|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         2|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         2|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         2|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         2|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         2|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+
# only showing top 20 rows
#
# +----------+
# |qa_engines|
# +----------+
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# |         2|
# +----------+
# only showing top 20 rows

# %% [markdown]
# Ver você

# %%
#with sql
qa_seats_df = spark.sql("""
    select
        *,
        case
            when 
               seats is null or seats like '' then 'M'
            when
                seats < 2 or seats > 500 then 'S'
            when
                 seats rlike '^([^0-9]*)$' = False
                then 'F'
            else
               seats
        end as qa_seats
    from planes_view
    """)
qa_seats_df.show()

planes_df = planes_df.withColumn("qa_seats", 
                when((col("seats") == "")      |
                    (col("seats").isNull()), "M")\
                .when((col("seats") < 2) |
                    (col('seats') > 500), "S")\
                .when((col('seats').rlike('^([^0-9]*)$') == False), "F")\
                .otherwise(col('seats'))
            )
planes_df.show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_seats|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|     149|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|     182|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|     330|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|     330|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|     178|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|     330|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# only showing top 20 rows
#
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|qa_year|qa_type| qa_manufacturer|qa_model|qa_engines|qa_seats|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1998|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         S|   2000|      M|          BOEING| 737-824|         2|       F|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1998|      M|          BOEING| 767-332|         2|       F|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1998|      M|          BOEING| 767-332|         2|       F|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         S|   1995|      M|          BOEING| 757-224|         2|       F|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1987|      M|          BOEING| 767-332|         2|       F|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+
# only showing top 20 rows

# %% [markdown]
# por

# %%
#with sql
qa_speed_df = spark.sql("""
    select
        *,
        case
            when 
               speed is null or speed like '' then 'M'
            when
                speed < 50.0 or speed > 150.0 then 'S'
            when
                 speed rlike '^([^0-9]*)$' = False
                then 'F'
            else
               speed
        end as qa_speed
    from planes_view
    """)
qa_speed_df.show()

planes_df = planes_df.withColumn("qa_speed", 
                when((col("speed") == "")      |
                    (col("speed").isNull()), "M")\
                .when((col("speed") < 50.0) |
                    (col('speed') > 150.0), "S")\
                .when((col('speed').rlike('^([^0-9]*)$') == False), "F")\
                .otherwise(col('speed'))
            )
planes_df.select('qa_speed').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_speed|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|       M|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|       M|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       M|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       M|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|       M|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       M|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# only showing top 20 rows
#
# +--------+
# |qa_speed|
# +--------+
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# |       M|
# +--------+
# only showing top 20 rows

# %% [markdown]
# aqui

# %%
engine_categories = ["Turbo-fan", "Turbo-jet","Turbo-prop","Turbo-prop","4 Cycle"]

#with sql
qa_engine_df = spark.sql("""
    select
        *,
        case
            when 
               engine is null or engine like '' then 'M'
            when
               engine not in ("Turbo-fan", "Turbo-jet","Turbo-prop","Turbo-prop","4 Cycle") 
               then 'C'
            else
               engine
        end as qa_engine
    from planes_view
    """)
qa_engine_df.show()

planes_df = planes_df.withColumn("qa_engine", 
                when((col("engine") == "")      |
                    (col("engine").isNull()), "M")\
                .when(
                    (col("engine").contains("Turbo-fan%")) |
                    (col("engine").contains("Turbo-jet%")) |
                    (col("engine").contains("Turbo-prop%")) |
                    (col("engine").contains("Turbo-shaft%"))   |
                    (col("engine").contains("Cycle%")), "C"
                    )\
                .otherwise(col('engine'))
            )
planes_df.select('qa_engine').show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+---------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_engine|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+---------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|Turbo-fan|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|Turbo-fan|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|Turbo-fan|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|Turbo-fan|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|Turbo-jet|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|Turbo-fan|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+---------+
# only showing top 20 rows
#
# +---------+
# |qa_engine|
# +---------+
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-fan|
# |Turbo-jet|
# |Turbo-fan|
# +---------+
# only showing top 20 rows

# %%
#Após feitas as transformações, vamos salvar nosso arquivo
planes_df.write.parquet("qa_outputs/planes_qa.parquet")
planes_df.show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+--------+---------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|qa_year|qa_type| qa_manufacturer|qa_model|qa_engines|qa_seats|qa_speed|qa_engine|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+--------+---------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1998|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         S|   2000|      M|          BOEING| 737-824|         2|       F|       M|Turbo-fan|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1998|      M|          BOEING| 767-332|         2|       F|       M|Turbo-fan|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1998|      M|          BOEING| 767-332|         2|       F|       M|Turbo-fan|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         S|   1995|      M|          BOEING| 757-224|         2|       F|       M|Turbo-jet|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1987|      M|          BOEING| 767-332|         2|       F|       M|Turbo-fan|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+--------+---------+
# only showing top 20 rows

# %% [markdown]
# e por fim, mas não menos importante
#
# # Flights Dataset
#
# ![Flight](attachment:./images/flight_snapshot.png "Flyng plane")
# <p style="text-align: center;"> <a href="./glossary/flights_glossary.txt"> Flight Glossary </a> </p>
#
# Para este último dataset não faremos nada diferete:

# %%
#vamos configura-lo

flights_file = "./datasets/flights.csv"

#set our schema (that you can see on glossary)
schema = StructType([
    StructField("year",  IntegerType()),
    StructField("month", IntegerType()),
    StructField("day",   IntegerType()),
    StructField("dep_time",  IntegerType()),
    StructField("dep_delay", IntegerType()),
    StructField("arr_time",  IntegerType()),
    StructField("arr_delay", IntegerType()),
    StructField("carrier",   StringType()),
    StructField("tailnum",   StringType()),
    StructField("flight",  IntegerType()),
    StructField("origin",  StringType()),
    StructField("destiny", StringType()),
    StructField("air_time", IntegerType()),
    StructField("distance", IntegerType()),
    StructField("hour",    IntegerType()),
    StructField("minute",  IntegerType())
])

#and create a new dataframe 
flights_df = spark \
           .read.format("csv") \
           .option("inferSchema", "false") \
           .option("header", "True")\
           .schema(schema)\
           .csv(flights_file)

#lets take the rdd to work with too
flights_rdd = flights_df.rdd

#don't forget to create a view (important to work with spark sql)
flights_df.createOrReplaceTempView('flights_view')

flights_df.show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+
# only showing top 20 rows

# %% [markdown]
# Para finalizar nosso trabalho, neste dataset temos tarefas a realizar que estão descritas a seguir:
#
#
# O que

# %%
#with sql
qa_year_month_day_df = spark.sql("""
    select
        *,
        case
            when 
               year is null or year like '' then 'MY'
            when 
               month is null or month like '' then 'MM'
            when 
               day is null or day like '' then 'MD'
            when
                year < 1950 then 'IY'
            when
                month < 1 or month > 12 then "IM"
            when
                (month == 2 and (day < 1 or day > 29)) or (month != 2 and (day < 1 or day > 31))
                then 'ID'
        end as qa_year_month_day
    from flights_view
    """)
qa_year_month_day_df.show()

flights_df = flights_df.withColumn("qa_year_month_day",
                when((col('year').isNull()) | 
                    ((col('year') == '')), 'MY')\
                .when( (col('month').isNull()) | 
                    (col('month') == ''), 'MM')\
                .when( (col('day').isNull()) | 
                    (col('day') == ''), 'MD')\
                .when((col('year') < 1950 ), "IY")\
                .when((col('month') < 1 ) |
                    (col('month') > 12 ), "IM")\
                .when((
                    (col('month') == 2) &
                    ((col('day') < 1 ) |
                    (col('day') > 29 ))
                    ) |
                    ((col('month') != 2) &
                    ((col('day') < 1 ) |
                    (col('day') > 31 ))
                    ), "ID")\
            )
flights_df.select('qa_year_month_day').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_year_month_day|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|             null|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|             null|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|             null|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|             null|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|             null|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|             null|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|             null|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|             null|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|             null|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|             null|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|             null|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|             null|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|             null|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|             null|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|             null|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|             null|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|             null|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|             null|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|             null|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|             null|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------------+
# only showing top 20 rows
#
# +-----------------+
# |qa_year_month_day|
# +-----------------+
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# |             null|
# +-----------------+
# only showing top 20 rows

# %% [markdown]
# Está

# %%
#with sql
qa_hour_minute_df = spark.sql("""
    select
        *,
        case
            when 
               carrier is null or carrier like '' then 'M'
            when
                length(carrier) != 2 then 'F'
            else
                carrier
        end as qa_hour_minute
    from flights_view
    """)
qa_hour_minute_df.show()

flights_df = flights_df.withColumn("qa_hour_minute",
                when((col('hour').isNull()) | 
                    ((col('hour') == '')), 'MH')\
                .when( (col('minute').isNull()) | 
                    (col('minute') == ''), 'MM')\
                .when( (length('hour') == 1) & ( (col('hour').substr(1,1) < 0) | (col('hour').substr(1,1) > 24) ) |
                    (length('hour') == 2) & ((col('hour').substr(1,2) < 0) | (col('hour').substr(1,2) > 24) ), 'IH')\
                .when( ((length('minute') == 1) & ((col('hour').substr(2,3) < 0) | (col('hour').substr(2,3) > 9))) |
                    ((length('minute') == 2) & ((col('hour').substr(3,4) < 0) | (col('hour').substr(3,4) > 59) )), 'IM')\
            )
flights_df.select('qa_hour_minute').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+--------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_hour_minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+--------------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|            VX|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|            AS|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|            VX|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|            WN|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|            AS|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|            WN|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|            WN|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|            VX|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|            AS|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|            AS|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|            AS|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|            AS|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|            AS|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|            AS|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|            AS|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|            UA|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|            AS|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|            WN|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|            AS|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|            OO|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+--------------+
# only showing top 20 rows
#
# +--------------+
# |qa_hour_minute|
# +--------------+
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# +--------------+
# only showing top 20 rows

# %% [markdown]
# achando

# %%
#with sql
qa_dep_arr_time_df = spark.sql("""
    select
        *,
        case
            when 
               carrier is null or carrier like '' then 'M'
            when
                length(carrier) != 2 then 'F'
            else
                carrier
        end as qa_dep_arr_delay
    from flights_view
    """)
qa_dep_arr_time_df.show()

flights_df = flights_df.withColumn("qa_dep_arr_time",
                when((col("dep_time") == "") |
                    (col("dep_time").isNull()), "MD")\
                .when((col("arr_time") == "") |
                    (col("arr_time").isNull()), "MA")
                .when( (length('dep_time') == 3) & ( (col('dep_time').substr(1,1) < 0) | (col('dep_time').substr(1,1) > 24) ) |
                    (length('dep_time') == 4) & ((col('dep_time').substr(1,2) < 0) | (col('dep_time').substr(1,2) > 24) ), 'FD')\
                .when( ((length('arr_time') == 3) & ((col('arr_time').substr(2,3) < 0) | (col('arr_time').substr(2,3) > 59))) |
                    ((length('arr_time') == 4) & ((col('arr_time').substr(3,4) < 0) | (col('arr_time').substr(3,4) > 59) )), 'FA')\
            )
flights_df.select('qa_dep_arr_time').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_dep_arr_delay|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|              VX|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|              AS|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|              VX|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|              WN|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|              AS|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|              WN|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|              WN|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|              VX|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|              AS|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|              AS|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|              AS|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|              AS|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|              AS|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|              AS|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|              AS|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|              UA|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|              AS|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|              WN|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|              AS|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|              OO|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------------+
# only showing top 20 rows
#
# +---------------+
# |qa_dep_arr_time|
# +---------------+
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# |           null|
# +---------------+
# only showing top 20 rows

# %% [markdown]
# do

# %%
#with sql
qa_dep_arr_delay_df = spark.sql("""
    select
        *,
        case
            when 
               dep_delay is null or dep_delay like '' then 'MD'
            when
                arr_delay is null or arr_delay like '' then 'MA'
        end as qa_dep_arr_delay
    from flights_view
    """)
qa_dep_arr_delay_df.show()

flights_df = flights_df.withColumn("qa_dep_arr_delay", 
                when((col("dep_delay") == "") |
                    (col("dep_delay").isNull()), "MD")\
                .when((col("arr_delay") == "") |
                    (col("arr_delay").isNull()), "MA")
            )
flights_df.select('qa_dep_arr_delay').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_dep_arr_delay|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|            null|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|            null|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|            null|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|            null|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|            null|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|            null|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|            null|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|            null|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|            null|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|            null|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|            null|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|            null|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|            null|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|            null|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|            null|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|            null|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|            null|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|            null|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|            null|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|            null|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------------+
# only showing top 20 rows
#
# +----------------+
# |qa_dep_arr_delay|
# +----------------+
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# |            null|
# +----------------+
# only showing top 20 rows

# %% [markdown]
# código

# %%
#with sql
qa_carrier_df = spark.sql("""
    select
        *,
        case
            when 
               carrier is null or carrier like '' then 'M'
            when
                length(carrier) != 2 then 'F'
            else
                carrier
        end as qa_carrier
    from flights_view
    """)
qa_carrier_df.show()

flights_df = flights_df.withColumn("qa_carrier", 
                when((col("carrier") == "") |
                    (col("carrier").isNull()), "M")\
                .when((length("carrier") != 2), "F")\
                .otherwise(col('carrier'))
            )
flights_df.select('qa_carrier').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_carrier|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|        VX|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|        AS|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|        VX|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|        WN|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|        AS|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|        WN|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|        WN|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|        VX|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|        AS|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|        AS|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|        AS|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|        AS|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|        AS|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|        AS|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|        AS|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|        UA|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|        AS|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|        WN|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|        AS|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|        OO|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# only showing top 20 rows
#
# +----------+
# |qa_carrier|
# +----------+
# |        VX|
# |        AS|
# |        VX|
# |        WN|
# |        AS|
# |        WN|
# |        WN|
# |        VX|
# |        AS|
# |        AS|
# |        AS|
# |        AS|
# |        AS|
# |        AS|
# |        AS|
# |        UA|
# |        AS|
# |        WN|
# |        AS|
# |        OO|
# +----------+
# only showing top 20 rows

# %% [markdown]
# até

# %%
#with sql
qa_tailnum_df = spark.sql("""
    select
        *,
        case
            when 
               tailnum is null or tailnum like '' then 'M'
            when
                length(tailnum) != 5 then 'S'
            when
                 substring(tailnum, 1, 1) not like 'N'
                     and
                     substring(tailnum, -1, -1) not like 'Z'
                     and
                 substring(tailnum, 2, 4) rlike '^([^0-9]*)$'
                then 'F'
            when 
                 substring(tailnum, 1, 1) = 'I' 
                     or
                 substring(tailnum, 1, 1) = 'O'
                     or
                 substring(tailnum, 1, 1) = '0' 
                then 'FE'
            when
                substring(tailnum, 1, 1) != 'I'
                then 'FN'
            else
               tailnum
        end as qa_tailnum
    from flights_view
    """)
qa_tailnum_df.show()

planes_df = planes_df.withColumn("qa_tailnum", 
                when((col("tailnum") == "")      |
                    (col("tailnum").isNull())   |
                    (col('tailnum').rlike('\t') |
                    (col('tailnum').rlike(' +'))), "M")\
                .when((length("tailnum") != 5), "S")\
                .when(
                    (col('tailnum').substr(1, 1) != 'N')   &
                    (col('tailnum').substr(-1, -1) != 'Z') & 
                    (col('tailnum').substr(2,4).rlike('^([^0-9]*)$')), "F")\
                .when((col("tailnum").substr(1,1) == "I")  |
                    (col("tailnum").substr(1,1) == "O") |
                    (col("tailnum").substr(1,1) == "0"), "FE")\
                .when((col("tailnum").substr(1,1) != "N"),  "FN")\
                .otherwise(col('tailnum'))
            )
planes_df.show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_tailnum|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|         S|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|         S|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|         S|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|         S|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|         S|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|         S|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|         S|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|         S|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|         S|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|         S|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|         S|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|         S|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|         S|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|         S|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|         S|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|         S|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|         S|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|         S|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|         S|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|         S|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# only showing top 20 rows
#
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+--------+---------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|qa_year|qa_type| qa_manufacturer|qa_model|qa_engines|qa_seats|qa_speed|qa_engine|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+--------+---------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1998|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         S|   2000|      M|          BOEING| 737-824|         2|       F|       M|Turbo-fan|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   1999|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|         S|   2000|      M|AIRBUS INDUSTRIE|A320-214|         2|       F|       M|Turbo-fan|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1998|      M|          BOEING| 767-332|         2|       F|       M|Turbo-fan|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1998|      M|          BOEING| 767-332|         2|       F|       M|Turbo-fan|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         S|   1995|      M|          BOEING| 757-224|         2|       F|       M|Turbo-jet|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|         S|   1987|      M|          BOEING| 767-332|         2|       F|       M|Turbo-fan|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+----------------+--------+----------+--------+--------+---------+
# only showing top 20 rows

# %% [markdown]
# o

# %%
#with sql
qa_flight_df = spark.sql("""
    select
        *,
        case
            when 
               flight is null or flight like '' then 'M'
            when
                flight rlike '([0-9]{4})' = False
                then 'F'
            else
               flight
        end as qa_flight
    from flights_view
    """)
qa_flight_df.show()

flights_df =flights_df.withColumn("qa_flight", 
                when((col("flight") == "") |
                    (col("flight").isNull()), "M")\
                .when((col('flight').rlike('[0-9]{4}') == False), "F")\
                .otherwise(col('flight'))
            )
flights_df.select('qa_flight').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+---------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_flight|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+---------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|     1780|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|      851|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|      755|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|      344|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|      522|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|       48|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|     1520|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|      755|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|      490|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|       26|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|      448|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|      656|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|      608|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|      121|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|      306|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|     1458|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|      368|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|      827|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|       24|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|     3488|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+---------+
# only showing top 20 rows
#
# +---------+
# |qa_flight|
# +---------+
# |     1780|
# |        F|
# |        F|
# |        F|
# |        F|
# |        F|
# |     1520|
# |        F|
# |        F|
# |        F|
# |        F|
# |        F|
# |        F|
# |        F|
# |        F|
# |     1458|
# |        F|
# |        F|
# |        F|
# |     3488|
# +---------+
# only showing top 20 rows

# %% [markdown]
# momento,

# %%
#with sql
qa_origin_dest_df = spark.sql("""
    select
        *,
        case
            when 
               origin is null or origin like '' then 'M'
            when 
               destiny is null or destiny like '' then 'M'
            when
                origin rlike '([A-Z]|[a-z]|[0-9]{3})' = False or length(origin) != 3
                then 'FO'
            when
                destiny rlike '([A-Z]|[a-z]|[0-9]{3})' = False or length(destiny) != 3
                then 'FD'
            end as qa_origin_dest
    from flights_view
    """)
qa_origin_dest_df.show()

flights_df = flights_df.withColumn("qa_origin_dest", 
                when((col("origin") == "") |
                    (col("origin").isNull()), "MO")\
                .when((col("destiny") == "") |
                    (col("destiny").isNull()), "MD")\
                .when(((col('origin').rlike('([A-Z]|[a-z]|[0-9]{3})') == False) | (length('origin') != 3)), "FO")\
                .when(((col('destiny').rlike('([A-Z]|[a-z]|[0-9]{3})') == False) | (length('destiny') != 3)), "FD")\
            )
flights_df.select('qa_origin_dest').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+--------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_origin_dest|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+--------------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|          null|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|          null|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|          null|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|          null|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|          null|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|          null|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|          null|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|          null|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|          null|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|          null|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|          null|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|          null|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|          null|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|          null|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|          null|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|          null|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|          null|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|          null|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|          null|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|          null|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+--------------+
# only showing top 20 rows
#
# +--------------+
# |qa_origin_dest|
# +--------------+
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# |          null|
# +--------------+
# only showing top 20 rows

# %% [markdown]
# meu

# %%
#with sql
qa_air_time_df = spark.sql("""
    select
        *,
        case
            when 
               air_time is null or air_time like '' then 'M'
            when
                air_time < 20 or air_time > 500 then 'I'
            else
               air_time
        end as qa_air_time
    from flights_view
    """)
qa_air_time_df.show()

flights_df = flights_df.withColumn("qa_air_time", 
                when((col("air_time") == "") |
                    (col("air_time").isNull()), "M")\
                .when((col("air_time") < 20) |
                    (col("air_time") > 500), "I")\
                .otherwise(col('air_time'))
            )
flights_df.select('qa_air_time').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_air_time|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|        132|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|        360|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|        111|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|         83|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|        127|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|        121|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|         90|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|         98|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|        135|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|        198|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|        130|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|        154|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|        127|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|        183|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|        129|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|         90|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|         76|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|        216|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|        290|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|        111|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------+
# only showing top 20 rows
#
# +-----------+
# |qa_air_time|
# +-----------+
# |        132|
# |        360|
# |        111|
# |         83|
# |        127|
# |        121|
# |         90|
# |         98|
# |        135|
# |        198|
# |        130|
# |        154|
# |        127|
# |        183|
# |        129|
# |         90|
# |         76|
# |        216|
# |        290|
# |        111|
# +-----------+
# only showing top 20 rows

# %% [markdown]
# caro

# %%
#with sql
qa_distance_df = spark.sql("""
    select
        *,
        case
            when 
               distance is null or distance like '' then 'M'
            when
                distance < 50 or distance > 3000 then 'I'
            else
               distance
        end as qa_distance
    from flights_view
    """)
qa_distance_df.show()

flights_df =flights_df.withColumn("qa_distance", 
                when((col("distance") == "") |
                    (col("distance").isNull()), "M")\
                .when((col("distance") < 50) |
                    (col("distance") > 3000), "I")\
                .otherwise(col('distance'))
            )
flights_df.select('qa_distance').show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_distance|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|        954|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|       2677|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|        679|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|        569|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|        937|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|        991|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|        543|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|        679|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|       1050|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|       1721|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|        954|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|       1107|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|        867|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|       1448|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|        679|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|        550|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|        605|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|       1733|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|       2496|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|        817|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------+
# only showing top 20 rows
#
# +-----------+
# |qa_distance|
# +-----------+
# |        954|
# |       2677|
# |        679|
# |        569|
# |        937|
# |        991|
# |        543|
# |        679|
# |       1050|
# |       1721|
# |        954|
# |       1107|
# |        867|
# |       1448|
# |        679|
# |        550|
# |        605|
# |       1733|
# |       2496|
# |        817|
# +-----------+
# only showing top 20 rows

# %% [markdown]
# curioso?

# %%
#with sql
qa_airtime_df = spark.sql("""
    select
        *,
        case
            when 
               air_time is null or air_time like '' then 'M'
            when
                air_time >= ( (distance * 0.1) + 30) then 'TL'
            when
                air_time <= ( (distance * 0.1) + 10) then 'TS'
            when
                (
                    (air_time >= ( (distance * .1) + 30)) and
                    (air_time <= ( (distance * .1) + 10))
                ) = False then 'TR'
        end as qa_airtime
    from flights_view
    """)
qa_airtime_df.show()

flights_df =flights_df.withColumn("qa_airtime", 
                when((col("air_time") == "") |
                    (col("air_time").isNull()), "M")\
                .when((col("air_time") >= (col('distance') * .1 ) + 30), "TL")\
                .when((col("air_time") <= (col('distance') * .1 ) + 10), "TS")\
                .when( ((col("air_time") >= (col('distance') * .1 ) + 30) &
                        ((col("air_time") <= (col('distance') * .1 ) + 10))) == False, "TR")\
            )
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_airtime|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|        TL|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|        TL|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|        TL|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|        TR|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|        TL|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|        TR|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|        TL|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|        TL|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|        TL|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|        TR|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|        TL|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|        TL|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|        TL|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|        TL|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|        TL|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|        TL|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|        TR|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|        TL|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|        TL|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|        TR|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+----------+
# only showing top 20 rows
#
# +----------+
# |qa_airtime|
# +----------+
# |        TL|
# |        TL|
# |        TL|
# |        TR|
# |        TL|
# |        TR|
# |        TL|
# |        TL|
# |        TL|
# |        TR|
# |        TL|
# |        TL|
# |        TL|
# |        TL|
# |        TL|
# |        TL|
# |        TR|
# |        TL|
# |        TL|
# |        TR|
# +----------+
# only showing top 20 rows

# %%
data = flights_df.withColumn('qa_dep_arr_delay', (
    F.when(
        ( (F.col('qa_dep_arr_delay').isNull())
        | (check_empty_column('qa_dep_arr_delay'))
        | (F.col('qa_dep_arr_delay') == None)), 'M'
    ).otherwise(
        F.col('qa_dep_arr_delay')
    )
))

data.show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------------+--------------+---------------+----------------+----------+---------+--------------+-----------+-----------+----------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|destiny|air_time|distance|hour|minute|qa_year_month_day|qa_hour_minute|qa_dep_arr_time|qa_dep_arr_delay|qa_carrier|qa_flight|qa_origin_dest|qa_air_time|qa_distance|qa_airtime|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------------+--------------+---------------+----------------+----------+---------+--------------+-----------+-----------+----------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|    LAX|     132|     954|   6|    58|             null|          null|           null|            null|        VX|     1780|          null|        132|        954|        TL|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|    HNL|     360|    2677|  10|    40|             null|          null|           null|            null|        AS|        F|          null|        360|       2677|        TL|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|    SFO|     111|     679|  14|    43|             null|          null|           null|            null|        VX|        F|          null|        111|        679|        TL|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|    SJC|      83|     569|  17|     5|             null|          null|           null|            null|        WN|        F|          null|         83|        569|        TR|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|    BUR|     127|     937|   7|    54|             null|          null|           null|            null|        AS|        F|          null|        127|        937|        TL|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX|    DEN|     121|     991|  10|    37|             null|          null|           null|            null|        WN|        F|          null|        121|        991|        TR|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX|    OAK|      90|     543|   8|    47|             null|          null|           null|            null|        WN|     1520|          null|         90|        543|        TL|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA|    SFO|      98|     679|  16|    55|             null|          null|           null|            null|        VX|        F|          null|         98|        679|        TL|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA|    SAN|     135|    1050|  12|    36|             null|          null|           null|            null|        AS|        F|          null|        135|       1050|        TL|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA|    ORD|     198|    1721|  18|    12|             null|          null|           null|            null|        AS|        F|          null|        198|       1721|        TR|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA|    LAX|     130|     954|  16|    53|             null|          null|           null|            null|        AS|        F|          null|        130|        954|        TL|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA|    PHX|     154|    1107|  11|    20|             null|          null|           null|            null|        AS|        F|          null|        154|       1107|        TL|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA|    LAS|     127|     867|   8|    11|             null|          null|           null|            null|        AS|        F|          null|        127|        867|        TL|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA|    ANC|     183|    1448|  23|    46|             null|          null|           null|            null|        AS|        F|          null|        183|       1448|        TL|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA|    SFO|     129|     679|  13|    14|             null|          null|           null|            null|        AS|        F|          null|        129|        679|        TL|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX|    SFO|      90|     550|  20|     9|             null|          null|           null|            null|        UA|     1458|          null|         90|        550|        TL|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA|    SMF|      76|     605|  20|    15|             null|          null|           null|            null|        AS|        F|          null|         76|        605|        TR|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA|    MDW|     216|    1733|  10|    17|             null|          null|           null|            null|        WN|        F|          null|        216|       1733|        TL|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA|    BOS|     290|    2496|  21|    56|             null|          null|           null|            null|        AS|        F|          null|        290|       2496|        TL|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX|    BUR|     111|     817|  17|    33|             null|          null|           null|            null|        OO|     3488|          null|        111|        817|        TR|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+-------+--------+--------+----+------+-----------------+--------------+---------------+----------------+----------+---------+--------------+-----------+-----------+----------+
# only showing top 20 rows

# %%
flights_df.write.parquet('qa_outputs/qa_flights')

# %%
# joining_dfs = airport_df.join(flights_df, ((airport_df.faa == flights_df.origin)), 'left')\
#                         .join(planes_df, (planes_df.tailnum == flights_df.tailnum), 'left')

# %%
# joining_dfs = joining_dfs.drop('tailnum', 'year')

# %%
joining_dfs.count()
# Out:
# 11395

# %%
# joining_dfs.write.parquet('outputs1/joined_data_new.parquet')
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
#     at line 885 in parquet(self, path, mode, partitionBy, compression)
#     at line 1309 in __call__(self, *args)
#     at line 117 in deco(*a, **kw)
# AnalysisException: path file:/data/notebook_files/outputs1/joined_data_new.parquet already exists.

# %%
# airport_qa = airport_df.drop('name', 'lat', 'lon', 'alt', 'tz', 'dst')
# planes_qa = planes_df.drop('year', 'type', 'manufacturer', 'model', 'engines', 'seats', 'speed', 'engine')
# flights_qa = flights_df.drop('year', 'month', 'day', 'dep_time', 'dep_delay', 'arr_time', 'arr_delay', 'carrier', 'flight', 
#                              'air_time', 'distance', 'hour', 'minute')

# %%
# from pyspark.sql import functions as F

# BD_qa_1 = flights_df.alias('fli').join(airport_df.alias('air'), 
#                                  F.col('fli.origin') == F.col('air.faa'), 'left')\
#                          .select(F.col("tailnum"),
#                                 F.col('origin'),
#                                F.col('destiny'),
#                                F.col('faa'),
#                                F.col('year_month_day_qa'),
#                                F.col('hour_minute_qa'), 
#                                F.col('dep_arr_time_qa'),
#                                F.col('dep_arr_delay_qa'),
#                                F.col('carrier_qa'),
#                                F.col('tailnum_qa'),
#                                F.col('flight_qa'),
#                                F.col('origin_dest_qa'),
#                                F.col('air_time_qa'),
#                                F.col('distance_qa'),
#                                F.col('distance_airtime_qa'),
#                                F.col('faa_qa').alias('ori_qa_faa'),
#                                F.col('name_qa').alias('ori_qa_name'),
#                                F.col('lat_qa').alias('ori_qa_lat'),
#                                F.col('lon_qa').alias('ori_qa_lon'),
#                                F.col('alt_qa').alias('ori_qa_alt'),
#                                F.col('tz_qa').alias('ori_qa_tz'),
#                                F.col('dst_qa').alias('ori_qa_dst'))
# BD_qa_1.show(5)

# %%
#Após feitas as transformações, vamos salvar nosso arquivo
#flights_df.write.parquet("output/flights_qa.parquet")

# %%
# all_dfs_join = airport_df.alias('a').join(flights_df.alias('b'),(airport_df['faa'] == flights_df['origin']),'left'
#             )\
#            .join(planes_df.alias('c')).where(planes_df['tailnum'] == flights_df['tailnum'])
           
# df_to_export = all_dfs_join.drop(*('tailnum', 'year'))
# df_to_export.show()

# %%
#df_to_export.write.parquet('outputs/all_join.parquet')

# %% [markdown]
# E com esse arquivo salvo (que lá em cima já vimos como efetuar a leitura), finalizamos a atividade da semana 2.
#
# Obrigado por ler e interagir até aqui!  <span style="font-size:25px">🖖</span>
#
# ![Thanks](attachment:./images/text-1647627553578.png "ThankU")

# %%
# joining_dfs.select('*').where(col('qa_seats').isNotNull()).show()
